# %%
import pandas as pd
import numpy as np


import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator 

import zipfile
import os
import shutil
import random

# %%
data = pd.read_csv("data.csv")
data.Fibrosis = data.Fibrosis.replace('-', np.NaN)
data.Equipment.value_counts()
# Out:
# IU22        101
# LOGIQE9      99
# iu22         78
# EUB-7500     70
# eub-7500     45
# S2000        28
# s2000         5
# Name: Equipment, dtype: int64

# %%
# to upper character

# data['Equipment'] = data['Equipment'].apply(lambda x: x.upper())

# %%
data['Equipment'] = 'A'

# %%
def sort_by_equipment(equipment):
    return data[(data['Equipment'] == equipment)]['Fibrosis'].value_counts()

# %%
data.Fibrosis = pd.to_numeric(data.Fibrosis)

# %%
# divide the data by Equipment

def fill_zero(f):
    for i in range(len(f)):
        f[i] = f[i].zfill(4)
    
    return f

def sort_by_tool(equipment):
    f_neg = data[(data['Fibrosis']==0) & (data['Equipment']==equipment.upper())].number.astype(str).tolist()
    f_pos = data[(data['Fibrosis']!=0) & (data['Equipment']==equipment.upper())].number.astype(str).tolist()
    
    # fill the zeros (for foloder name)
    f_neg = fill_zero(f_neg)
    f_pos = fill_zero(f_pos)
    
    return f_neg, f_pos


def move_to_tmp(local_zip, equipment, base_loc):
    zip_ref = zipfile.ZipFile(local_zip, 'r')
    zip_ref.extractall('/tmp/Liver_'+equipment)
    zip_ref.close()

def make_folder(base_loc):
    try:
        os.mkdir(base_loc)
        os.mkdir(base_loc+'/training')
        os.mkdir(base_loc+'/training/f0')
        os.mkdir(base_loc+'/training/f1')
        os.mkdir(base_loc+'/testing')
        os.mkdir(base_loc+'/testing/f0')
        os.mkdir(base_loc+'/testing/f1')

    except OSError:
        pass

def move_to_folder(f_, folder_loc, split, base_loc):
    split = int(len(f_)*(1-split))
    
    f_train = f_[:split]
    f_test = f_[split:]
    
    print(folder_loc,':',len(f_train))
    print(folder_loc,':',len(f_test))
    
    new_name = 0
    for folder_name in f_train:
        for root, subdirs, files in os.walk(base_loc+'/'+folder_name):
            for f in files:
                if 'mask' not in f:
                    # file_name change
                    try:
                        file_to_change = os.path.join(root, f)
                        dst = str(new_name)+'.tif'
                        dst = os.path.join(root, dst)
                        # print(file_to_change, new_name)
                        
                        os.rename(file_to_change, dst)
                        new_name += 1
                        tmp = base_loc+'/training/'+folder_loc
                        # file move
                        shutil.move(dst, tmp)
                    except:
                        print('error')
    
    new_name = 0                    
    for folder_name in f_test:
        for root, subdirs, files in os.walk(base_loc+'/'+folder_name):
            for f in files:
                if 'mask' not in f:
                    # file_name change
                    try:
                        file_to_change = os.path.join(root, f)
                        dst = str(new_name)+'.tif'
                        # print(file_to_change, new_name)
                        
                        dst = os.path.join(root, dst)
                        os.rename(file_to_change, dst)
                        new_name += 1
                        tmp = base_loc+'/testing/'+folder_loc
                        # file move
                        shutil.move(dst, tmp)
                    except:
                        print('error')

# %%
def train_test_split(equipment, local_zip, split_size):
    equipment = equipment.upper()
    f_false, f_true = sort_by_tool(equipment)
    
    random.shuffle(f_false)
    random.shuffle(f_true)
    
    make_folder(base_loc)
    move_to_tmp(local_zip, equipment, base_loc)
    
    move_to_folder(f_false, 'f0', 0.2, base_loc)
    move_to_folder(f_true, 'f1', 0.2, base_loc)

# %%
def ImageGenerator(base_loc):
    TRAINING_DIR = base_loc+'/training'
    train_datagen = ImageDataGenerator(rescale = 1./255.)

    train_generator = train_datagen.flow_from_directory(TRAINING_DIR,
                                                       batch_size=8,
                                                       class_mode='binary',
                                                       target_size=(600,800),
                                                       color_mode='rgb') # target_size = (height, width)

    TESTING_DIR = base_loc+'/testing'
    test_datagen = ImageDataGenerator(rescale = 1.0/255.)

    test_generator = train_datagen.flow_from_directory(TESTING_DIR,
                                                       batch_size=16,
                                                       class_mode='binary',
                                                       target_size=(600,800), 
                                                       color_mode='rgb')
    
    return train_generator, test_generator

# %%
# change
equipment = 'A' 
local_zip = '../../../Data/Liver10.zip'
base_loc = '/tmp/Liver_' + equipment

# %%
train_test_split(equipment, local_zip, 0.2)
# Out:
# f0 : 116
# f0 : 30
# f1 : 224
# f1 : 56

# %%
# training

# error files:
# 1881/mask/1881-0006.tif
# 1813/mask/1813-0002.tif
# 2103/mask/2013-0001.tif

# %%
print("Training Fibrosis 0:", len(os.listdir(base_loc+'/training/f0')))
print("Testing Fibrosis 0:", len(os.listdir(base_loc+'/testing/f0')))
print("-"*25)
print("Training Fibrosis 1:", len(os.listdir(base_loc+'/training/f1')))
print("Testing Fibrosis 1:", len(os.listdir(base_loc+'/testing/f1')))
# Out:
# Training Fibrosis 0: 886
# Testing Fibrosis 0: 223
# -------------------------
# Training Fibrosis 1: 1572
# Testing Fibrosis 1: 400

# %%
train_generator, test_generator = ImageGenerator(base_loc)
# Out:
# Found 2458 images belonging to 2 classes.
# Found 623 images belonging to 2 classes.

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
            logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# ## Simple Res Model

# %%
from tensorflow.keras.layers import Layer

# %%
class IdentityBlock(tf.keras.Model):
    def __init__(self, filters, kernel_size):
        super(IdentityBlock, self).__init__(name='')
        
        self.conv1 = tf.keras.layers.Conv2D(filters, kernel_size, padding='same')
        self.bn1 = tf.keras.layers.BatchNormalization()
        
        self.conv2 = tf.keras.layers.Conv2D(filters, kernel_size, padding='same')
        self.bn2 = tf.keras.layers.BatchNormalization()
        
        self.act = tf.keras.layers.Activation('relu')
        self.add = tf.keras.layers.Add()
        
    def call(self, input_tensor):
        X = self.conv1(input_tensor)
        X = self.bn1(X)
        X = self.act(X)
        
        X = self.conv2(X)
        X = self.bn2(X)
        
        X = self.add([X, input_tensor])
        X = self.act(X)
        return X
    
class ResNet(tf.keras.Model):
    def __init__(self, num_classes):
        super(ResNet, self).__init__()
        self.conv = tf.keras.layers.Conv2D(64, 7, padding='same')
        self.bn = tf.keras.layers.BatchNormalization()
        self.act = tf.keras.layers.Activation('relu')
        self.max_pool = tf.keras.layers.MaxPool2D((3, 3))

        # Use the Identity blocks that you just defined
        self.id1a = IdentityBlock(64, 3)
        self.id1b = IdentityBlock(64, 3)

        self.global_pool = tf.keras.layers.GlobalAveragePooling2D()
        
        self.flatten = tf.keras.layers.Flatten()
        self.drop = tf.keras.layers.Dropout(0.4)
        self.dense_1 = tf.keras.layers.Dense(1024, activation='sigmoid')
        self.dense_2 = tf.keras.layers.Dense(512, activation='sigmoid')
        self.classifier = tf.keras.layers.Dense(num_classes, activation='sigmoid')

    def call(self, inputs):
        x = self.conv(inputs)
        x = self.bn(x)
        x = self.act(x)
        x = self.max_pool(x)

        # insert the identity blocks in the middle of the network
        x = self.id1a(x)
        x = self.id1b(x)
        x = self.global_pool(x)
        
        x = self.flatten(x)
        x = self.drop(x)
        x = self.dense_1(x)
        x = self.dense_2(x)
        
        return self.classifier(x)

# %%
resnet = ResNet(1)

# %%
resnet.compile(optimizer=tf.keras.optimizers.Adam(lr=0.0001),
               loss=tf.keras.losses.BinaryCrossentropy(),
               metrics=['accuracy'])

# %%
history = resnet.fit(train_generator,
           epochs=50,
           validation_data=test_generator)
# Out:
# Epoch 1/50
#   2/308 [..............................] - ETA: 27s - loss: 0.6397 - accuracy: 0.6875WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0684s vs `on_train_batch_end` time: 0.1081s). Check your callbacks.
# 308/308 [==============================] - 59s 192ms/step - loss: 0.6646 - accuracy: 0.6225 - val_loss: 0.6447 - val_accuracy: 0.6421
# Epoch 2/50
# 308/308 [==============================] - 59s 191ms/step - loss: 0.6524 - accuracy: 0.6265 - val_loss: 0.6495 - val_accuracy: 0.6421
# Epoch 3/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.6366 - accuracy: 0.6477 - val_loss: 1.0409 - val_accuracy: 0.3596
# Epoch 4/50
# 308/308 [==============================] - 59s 191ms/step - loss: 0.6183 - accuracy: 0.6635 - val_loss: 0.8037 - val_accuracy: 0.3997
# Epoch 5/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.6079 - accuracy: 0.6701 - val_loss: 0.9289 - val_accuracy: 0.3579
# Epoch 6/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5949 - accuracy: 0.6827 - val_loss: 0.6802 - val_accuracy: 0.5746
# Epoch 7/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.6055 - accuracy: 0.6770 - val_loss: 1.2021 - val_accuracy: 0.3692
# Epoch 8/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5906 - accuracy: 0.6961 - val_loss: 0.8525 - val_accuracy: 0.5088
# Epoch 9/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5907 - accuracy: 0.6884 - val_loss: 0.6567 - val_accuracy: 0.6212
# Epoch 10/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5907 - accuracy: 0.6932 - val_loss: 0.6191 - val_accuracy: 0.6501
# Epoch 11/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5913 - accuracy: 0.6884 - val_loss: 0.6177 - val_accuracy: 0.6388
# Epoch 12/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5877 - accuracy: 0.6823 - val_loss: 0.8097 - val_accuracy: 0.5377
# Epoch 13/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5847 - accuracy: 0.6969 - val_loss: 0.6127 - val_accuracy: 0.6501
# Epoch 14/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5843 - accuracy: 0.6953 - val_loss: 0.6493 - val_accuracy: 0.6212
# Epoch 15/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5820 - accuracy: 0.6985 - val_loss: 0.6229 - val_accuracy: 0.6533
# Epoch 16/50
# 308/308 [==============================] - 59s 193ms/step - loss: 0.5754 - accuracy: 0.7034 - val_loss: 0.6946 - val_accuracy: 0.6116
# Epoch 17/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5712 - accuracy: 0.7087 - val_loss: 0.6620 - val_accuracy: 0.6340
# Epoch 18/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5705 - accuracy: 0.7124 - val_loss: 0.6576 - val_accuracy: 0.6469
# Epoch 19/50
# 308/308 [==============================] - 59s 193ms/step - loss: 0.5674 - accuracy: 0.7071 - val_loss: 0.6243 - val_accuracy: 0.6324
# Epoch 20/50
# 308/308 [==============================] - 59s 193ms/step - loss: 0.5720 - accuracy: 0.7050 - val_loss: 0.6361 - val_accuracy: 0.6597
# Epoch 21/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5688 - accuracy: 0.7111 - val_loss: 0.6352 - val_accuracy: 0.6453
# Epoch 22/50
# 308/308 [==============================] - 59s 193ms/step - loss: 0.5747 - accuracy: 0.7071 - val_loss: 0.7144 - val_accuracy: 0.6019
# Epoch 23/50
# 308/308 [==============================] - 59s 193ms/step - loss: 0.5648 - accuracy: 0.7095 - val_loss: 0.7500 - val_accuracy: 0.6100
# Epoch 24/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5779 - accuracy: 0.7026 - val_loss: 0.7655 - val_accuracy: 0.6469
# Epoch 25/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5638 - accuracy: 0.7160 - val_loss: 0.6769 - val_accuracy: 0.6228
# Epoch 26/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5635 - accuracy: 0.7055 - val_loss: 0.6308 - val_accuracy: 0.6661
# Epoch 27/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5595 - accuracy: 0.7120 - val_loss: 0.6221 - val_accuracy: 0.6677
# Epoch 28/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5529 - accuracy: 0.7307 - val_loss: 0.7018 - val_accuracy: 0.6421
# Epoch 29/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5591 - accuracy: 0.7213 - val_loss: 0.6192 - val_accuracy: 0.6661
# Epoch 30/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5578 - accuracy: 0.7299 - val_loss: 0.6064 - val_accuracy: 0.6758
# Epoch 31/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5654 - accuracy: 0.7124 - val_loss: 0.6169 - val_accuracy: 0.6693
# Epoch 32/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5626 - accuracy: 0.7209 - val_loss: 0.6261 - val_accuracy: 0.6790
# Epoch 33/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5611 - accuracy: 0.7103 - val_loss: 0.6409 - val_accuracy: 0.6790
# Epoch 34/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5546 - accuracy: 0.7168 - val_loss: 0.6582 - val_accuracy: 0.6421
# Epoch 35/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5566 - accuracy: 0.7221 - val_loss: 0.6469 - val_accuracy: 0.6469
# Epoch 36/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5554 - accuracy: 0.7128 - val_loss: 0.6217 - val_accuracy: 0.6356
# Epoch 37/50
# 308/308 [==============================] - 59s 191ms/step - loss: 0.5479 - accuracy: 0.7201 - val_loss: 0.6107 - val_accuracy: 0.6597
# Epoch 38/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5535 - accuracy: 0.7213 - val_loss: 0.6149 - val_accuracy: 0.6549
# Epoch 39/50
# 308/308 [==============================] - 59s 191ms/step - loss: 0.5454 - accuracy: 0.7286 - val_loss: 0.7764 - val_accuracy: 0.6100
# Epoch 40/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5571 - accuracy: 0.7221 - val_loss: 0.7760 - val_accuracy: 0.6501
# Epoch 41/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5581 - accuracy: 0.7164 - val_loss: 0.6753 - val_accuracy: 0.6517
# Epoch 42/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5533 - accuracy: 0.7250 - val_loss: 0.6256 - val_accuracy: 0.6742
# Epoch 43/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5505 - accuracy: 0.7217 - val_loss: 0.6189 - val_accuracy: 0.6533
# Epoch 44/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5437 - accuracy: 0.7421 - val_loss: 0.5955 - val_accuracy: 0.6918
# Epoch 45/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5560 - accuracy: 0.7156 - val_loss: 0.7428 - val_accuracy: 0.6421
# Epoch 46/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5490 - accuracy: 0.7250 - val_loss: 0.6554 - val_accuracy: 0.6533
# Epoch 47/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5410 - accuracy: 0.7295 - val_loss: 0.6003 - val_accuracy: 0.6758
# Epoch 48/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5500 - accuracy: 0.7266 - val_loss: 0.8688 - val_accuracy: 0.6421
# Epoch 49/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5416 - accuracy: 0.7299 - val_loss: 0.7700 - val_accuracy: 0.6421
# Epoch 50/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5404 - accuracy: 0.7376 - val_loss: 0.6149 - val_accuracy: 0.6806

# %%
import matplotlib.pyplot as plt

def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()
    
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %%
history2 = resnet.fit(train_generator,
           epochs=50,
           validation_data=test_generator)
# Out:
# Epoch 1/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5492 - accuracy: 0.7229 - val_loss: 0.5964 - val_accuracy: 0.6790
# Epoch 2/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5382 - accuracy: 0.7384 - val_loss: 0.6125 - val_accuracy: 0.6742
# Epoch 3/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5436 - accuracy: 0.7323 - val_loss: 0.6302 - val_accuracy: 0.6677
# Epoch 4/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5429 - accuracy: 0.7274 - val_loss: 0.6393 - val_accuracy: 0.6501
# Epoch 5/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5385 - accuracy: 0.7372 - val_loss: 1.1774 - val_accuracy: 0.4093
# Epoch 6/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5476 - accuracy: 0.7307 - val_loss: 0.6102 - val_accuracy: 0.6693
# Epoch 7/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5339 - accuracy: 0.7392 - val_loss: 0.6257 - val_accuracy: 0.6822
# Epoch 8/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5461 - accuracy: 0.7339 - val_loss: 0.6053 - val_accuracy: 0.6613
# Epoch 9/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5419 - accuracy: 0.7278 - val_loss: 0.6825 - val_accuracy: 0.6421
# Epoch 10/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5362 - accuracy: 0.7388 - val_loss: 0.5952 - val_accuracy: 0.6790
# Epoch 11/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5320 - accuracy: 0.7417 - val_loss: 0.6722 - val_accuracy: 0.6565
# Epoch 12/50
# 308/308 [==============================] - 59s 191ms/step - loss: 0.5395 - accuracy: 0.7408 - val_loss: 0.6368 - val_accuracy: 0.6742
# Epoch 13/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5396 - accuracy: 0.7376 - val_loss: 0.6461 - val_accuracy: 0.6388
# Epoch 14/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5338 - accuracy: 0.7417 - val_loss: 0.5822 - val_accuracy: 0.7047
# Epoch 15/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5298 - accuracy: 0.7486 - val_loss: 0.7697 - val_accuracy: 0.5955
# Epoch 16/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5357 - accuracy: 0.7461 - val_loss: 0.9360 - val_accuracy: 0.5104
# Epoch 17/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5315 - accuracy: 0.7482 - val_loss: 0.5902 - val_accuracy: 0.7095
# Epoch 18/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5300 - accuracy: 0.7384 - val_loss: 0.8637 - val_accuracy: 0.6421
# Epoch 19/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5318 - accuracy: 0.7469 - val_loss: 0.6517 - val_accuracy: 0.6565
# Epoch 20/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5356 - accuracy: 0.7392 - val_loss: 0.6210 - val_accuracy: 0.6918
# Epoch 21/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5393 - accuracy: 0.7352 - val_loss: 0.6146 - val_accuracy: 0.6774
# Epoch 22/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5285 - accuracy: 0.7449 - val_loss: 0.5906 - val_accuracy: 0.6726
# Epoch 23/50
# 308/308 [==============================] - 59s 193ms/step - loss: 0.5346 - accuracy: 0.7343 - val_loss: 0.6583 - val_accuracy: 0.6645
# Epoch 24/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5293 - accuracy: 0.7457 - val_loss: 0.7445 - val_accuracy: 0.6196
# Epoch 25/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5328 - accuracy: 0.7343 - val_loss: 0.6063 - val_accuracy: 0.6918
# Epoch 26/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5300 - accuracy: 0.7404 - val_loss: 0.6148 - val_accuracy: 0.6966
# Epoch 27/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5340 - accuracy: 0.7425 - val_loss: 0.6028 - val_accuracy: 0.6758
# Epoch 28/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5272 - accuracy: 0.7469 - val_loss: 0.5805 - val_accuracy: 0.6934
# Epoch 29/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5354 - accuracy: 0.7404 - val_loss: 0.5787 - val_accuracy: 0.7207
# Epoch 30/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5274 - accuracy: 0.7429 - val_loss: 0.6243 - val_accuracy: 0.6838
# Epoch 31/50
# 308/308 [==============================] - 59s 191ms/step - loss: 0.5277 - accuracy: 0.7510 - val_loss: 0.6239 - val_accuracy: 0.6709
# Epoch 32/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5241 - accuracy: 0.7498 - val_loss: 0.6341 - val_accuracy: 0.6693
# Epoch 33/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5295 - accuracy: 0.7368 - val_loss: 0.6231 - val_accuracy: 0.6998
# Epoch 34/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5257 - accuracy: 0.7437 - val_loss: 0.5995 - val_accuracy: 0.6950
# Epoch 35/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5256 - accuracy: 0.7506 - val_loss: 0.8745 - val_accuracy: 0.5249
# Epoch 36/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5254 - accuracy: 0.7547 - val_loss: 0.6292 - val_accuracy: 0.6950
# Epoch 37/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5253 - accuracy: 0.7490 - val_loss: 0.6367 - val_accuracy: 0.6758
# Epoch 38/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5153 - accuracy: 0.7636 - val_loss: 0.6859 - val_accuracy: 0.6517
# Epoch 39/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5279 - accuracy: 0.7376 - val_loss: 0.7240 - val_accuracy: 0.5939
# Epoch 40/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5289 - accuracy: 0.7453 - val_loss: 0.6611 - val_accuracy: 0.6613
# Epoch 41/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5242 - accuracy: 0.7490 - val_loss: 0.5862 - val_accuracy: 0.6854
# Epoch 42/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5209 - accuracy: 0.7547 - val_loss: 0.6652 - val_accuracy: 0.6645
# Epoch 43/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5358 - accuracy: 0.7380 - val_loss: 0.5737 - val_accuracy: 0.6870
# Epoch 44/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5238 - accuracy: 0.7522 - val_loss: 0.7275 - val_accuracy: 0.6083
# Epoch 45/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5180 - accuracy: 0.7486 - val_loss: 0.6551 - val_accuracy: 0.6677
# Epoch 46/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5211 - accuracy: 0.7461 - val_loss: 0.7564 - val_accuracy: 0.6019
# Epoch 47/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5216 - accuracy: 0.7531 - val_loss: 0.5676 - val_accuracy: 0.7127
# Epoch 48/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5255 - accuracy: 0.7445 - val_loss: 0.7642 - val_accuracy: 0.6212
# Epoch 49/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5175 - accuracy: 0.7579 - val_loss: 0.5711 - val_accuracy: 0.7047
# Epoch 50/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5117 - accuracy: 0.7514 - val_loss: 0.5976 - val_accuracy: 0.6966

# %%
plot_graphs(history2, "accuracy")
plot_graphs(history2, "loss")

# %%
history3 = resnet.fit(train_generator,
           epochs=50,
           validation_data=test_generator)
# Out:
# Epoch 1/50
#   2/308 [..............................] - ETA: 44s - loss: 0.3885 - accuracy: 0.8750WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0703s vs `on_train_batch_end` time: 0.1086s). Check your callbacks.
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5182 - accuracy: 0.7551 - val_loss: 0.9448 - val_accuracy: 0.6421
# Epoch 2/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5171 - accuracy: 0.7506 - val_loss: 0.6813 - val_accuracy: 0.6501
# Epoch 3/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5222 - accuracy: 0.7551 - val_loss: 0.5961 - val_accuracy: 0.6822
# Epoch 4/50
# 308/308 [==============================] - 59s 193ms/step - loss: 0.5117 - accuracy: 0.7612 - val_loss: 0.5845 - val_accuracy: 0.7014
# Epoch 5/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5176 - accuracy: 0.7494 - val_loss: 0.6041 - val_accuracy: 0.6966
# Epoch 6/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5200 - accuracy: 0.7567 - val_loss: 0.7664 - val_accuracy: 0.5987
# Epoch 7/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5189 - accuracy: 0.7539 - val_loss: 0.5785 - val_accuracy: 0.7014
# Epoch 8/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5197 - accuracy: 0.7494 - val_loss: 0.6309 - val_accuracy: 0.6645
# Epoch 9/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5137 - accuracy: 0.7604 - val_loss: 0.6001 - val_accuracy: 0.7143
# Epoch 10/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5205 - accuracy: 0.7514 - val_loss: 0.5704 - val_accuracy: 0.7095
# Epoch 11/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5077 - accuracy: 0.7636 - val_loss: 0.5659 - val_accuracy: 0.7255
# Epoch 12/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5153 - accuracy: 0.7522 - val_loss: 0.7856 - val_accuracy: 0.5586
# Epoch 13/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5158 - accuracy: 0.7579 - val_loss: 0.5555 - val_accuracy: 0.7368
# Epoch 14/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5070 - accuracy: 0.7616 - val_loss: 0.6572 - val_accuracy: 0.6533
# Epoch 15/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5132 - accuracy: 0.7636 - val_loss: 0.5681 - val_accuracy: 0.7255
# Epoch 16/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5154 - accuracy: 0.7583 - val_loss: 0.5901 - val_accuracy: 0.6998
# Epoch 17/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5164 - accuracy: 0.7506 - val_loss: 0.5660 - val_accuracy: 0.7191
# Epoch 18/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5171 - accuracy: 0.7457 - val_loss: 0.5845 - val_accuracy: 0.7111
# Epoch 19/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5119 - accuracy: 0.7563 - val_loss: 0.6061 - val_accuracy: 0.6806
# Epoch 20/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5182 - accuracy: 0.7514 - val_loss: 0.6290 - val_accuracy: 0.6726
# Epoch 21/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5142 - accuracy: 0.7567 - val_loss: 0.6118 - val_accuracy: 0.6902
# Epoch 22/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5208 - accuracy: 0.7518 - val_loss: 0.6318 - val_accuracy: 0.6613
# Epoch 23/50
# 308/308 [==============================] - 59s 193ms/step - loss: 0.5108 - accuracy: 0.7583 - val_loss: 0.5758 - val_accuracy: 0.7127
# Epoch 24/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5059 - accuracy: 0.7628 - val_loss: 0.5766 - val_accuracy: 0.7271
# Epoch 25/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5075 - accuracy: 0.7669 - val_loss: 0.7298 - val_accuracy: 0.5939
# Epoch 26/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5156 - accuracy: 0.7543 - val_loss: 0.7067 - val_accuracy: 0.6469
# Epoch 27/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5001 - accuracy: 0.7685 - val_loss: 0.5984 - val_accuracy: 0.7223
# Epoch 28/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5082 - accuracy: 0.7592 - val_loss: 0.7913 - val_accuracy: 0.5714
# Epoch 29/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5026 - accuracy: 0.7705 - val_loss: 0.6791 - val_accuracy: 0.6324
# Epoch 30/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5147 - accuracy: 0.7579 - val_loss: 0.7181 - val_accuracy: 0.6132
# Epoch 31/50
# 308/308 [==============================] - 59s 193ms/step - loss: 0.5045 - accuracy: 0.7592 - val_loss: 0.5844 - val_accuracy: 0.7127
# Epoch 32/50
# 308/308 [==============================] - 60s 194ms/step - loss: 0.5031 - accuracy: 0.7673 - val_loss: 0.6624 - val_accuracy: 0.6308
# Epoch 33/50
# 308/308 [==============================] - 59s 193ms/step - loss: 0.5127 - accuracy: 0.7624 - val_loss: 0.6126 - val_accuracy: 0.6709
# Epoch 34/50
# 308/308 [==============================] - 60s 194ms/step - loss: 0.5080 - accuracy: 0.7551 - val_loss: 0.6469 - val_accuracy: 0.6549
# Epoch 35/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5020 - accuracy: 0.7714 - val_loss: 0.7319 - val_accuracy: 0.6260
# Epoch 36/50
# 308/308 [==============================] - 60s 193ms/step - loss: 0.5076 - accuracy: 0.7498 - val_loss: 0.5687 - val_accuracy: 0.7079
# Epoch 37/50
# 308/308 [==============================] - 60s 194ms/step - loss: 0.5155 - accuracy: 0.7559 - val_loss: 0.5951 - val_accuracy: 0.6822
# Epoch 38/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5135 - accuracy: 0.7600 - val_loss: 0.6362 - val_accuracy: 0.6758
# Epoch 39/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5079 - accuracy: 0.7587 - val_loss: 0.7879 - val_accuracy: 0.5570
# Epoch 40/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5033 - accuracy: 0.7653 - val_loss: 0.5487 - val_accuracy: 0.7416
# Epoch 41/50
# 308/308 [==============================] - 59s 191ms/step - loss: 0.5017 - accuracy: 0.7681 - val_loss: 0.5796 - val_accuracy: 0.6982
# Epoch 42/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4963 - accuracy: 0.7689 - val_loss: 0.6603 - val_accuracy: 0.6581
# Epoch 43/50
# 308/308 [==============================] - 60s 193ms/step - loss: 0.5004 - accuracy: 0.7681 - val_loss: 0.5531 - val_accuracy: 0.7560
# Epoch 44/50
# 308/308 [==============================] - 59s 193ms/step - loss: 0.5007 - accuracy: 0.7726 - val_loss: 0.5786 - val_accuracy: 0.7063
# Epoch 45/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4971 - accuracy: 0.7823 - val_loss: 0.7010 - val_accuracy: 0.6244
# Epoch 46/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5021 - accuracy: 0.7571 - val_loss: 0.5777 - val_accuracy: 0.7111
# Epoch 47/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4998 - accuracy: 0.7624 - val_loss: 0.5818 - val_accuracy: 0.6934
# Epoch 48/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5052 - accuracy: 0.7612 - val_loss: 0.5750 - val_accuracy: 0.7143
# Epoch 49/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5066 - accuracy: 0.7628 - val_loss: 0.5667 - val_accuracy: 0.7271
# Epoch 50/50
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5023 - accuracy: 0.7644 - val_loss: 0.5824 - val_accuracy: 0.7255

# %%
plot_graphs(history3, "accuracy")
plot_graphs(history3, "loss")

# %%
history4 = resnet.fit(train_generator,
           epochs=200,
           validation_data=test_generator)
# Out:
# Epoch 1/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.5038 - accuracy: 0.7567 - val_loss: 0.5575 - val_accuracy: 0.7464
# Epoch 2/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.5047 - accuracy: 0.7567 - val_loss: 0.5481 - val_accuracy: 0.7448
# Epoch 3/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4984 - accuracy: 0.7730 - val_loss: 0.5642 - val_accuracy: 0.7335
# Epoch 4/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4937 - accuracy: 0.7746 - val_loss: 0.5876 - val_accuracy: 0.7239
# Epoch 5/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5017 - accuracy: 0.7697 - val_loss: 0.5814 - val_accuracy: 0.6950
# Epoch 6/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.5026 - accuracy: 0.7718 - val_loss: 0.6063 - val_accuracy: 0.7047
# Epoch 7/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4961 - accuracy: 0.7722 - val_loss: 0.5604 - val_accuracy: 0.7191
# Epoch 8/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4928 - accuracy: 0.7766 - val_loss: 0.5989 - val_accuracy: 0.7159
# Epoch 9/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4984 - accuracy: 0.7718 - val_loss: 0.5717 - val_accuracy: 0.7287
# Epoch 10/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5033 - accuracy: 0.7677 - val_loss: 0.5671 - val_accuracy: 0.7127
# Epoch 11/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5055 - accuracy: 0.7685 - val_loss: 0.5856 - val_accuracy: 0.7143
# Epoch 12/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4948 - accuracy: 0.7689 - val_loss: 0.6470 - val_accuracy: 0.6870
# Epoch 13/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4979 - accuracy: 0.7714 - val_loss: 0.5771 - val_accuracy: 0.7223
# Epoch 14/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4935 - accuracy: 0.7742 - val_loss: 0.6105 - val_accuracy: 0.6790
# Epoch 15/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4908 - accuracy: 0.7697 - val_loss: 0.6906 - val_accuracy: 0.6581
# Epoch 16/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5055 - accuracy: 0.7632 - val_loss: 0.5865 - val_accuracy: 0.6854
# Epoch 17/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4917 - accuracy: 0.7697 - val_loss: 0.5645 - val_accuracy: 0.7384
# Epoch 18/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4887 - accuracy: 0.7807 - val_loss: 0.6362 - val_accuracy: 0.6742
# Epoch 19/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5003 - accuracy: 0.7746 - val_loss: 0.5989 - val_accuracy: 0.6806
# Epoch 20/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5011 - accuracy: 0.7697 - val_loss: 0.6548 - val_accuracy: 0.6453
# Epoch 21/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.5033 - accuracy: 0.7685 - val_loss: 0.5925 - val_accuracy: 0.6918
# Epoch 22/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4952 - accuracy: 0.7730 - val_loss: 0.5946 - val_accuracy: 0.7255
# Epoch 23/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4988 - accuracy: 0.7718 - val_loss: 0.5773 - val_accuracy: 0.7175
# Epoch 24/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4981 - accuracy: 0.7677 - val_loss: 0.5711 - val_accuracy: 0.7239
# Epoch 25/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4978 - accuracy: 0.7628 - val_loss: 0.6311 - val_accuracy: 0.6517
# Epoch 26/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4869 - accuracy: 0.7758 - val_loss: 0.5709 - val_accuracy: 0.7319
# Epoch 27/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4894 - accuracy: 0.7799 - val_loss: 0.5987 - val_accuracy: 0.7030
# Epoch 28/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4932 - accuracy: 0.7738 - val_loss: 0.6241 - val_accuracy: 0.6693
# Epoch 29/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4958 - accuracy: 0.7799 - val_loss: 0.7148 - val_accuracy: 0.6404
# Epoch 30/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4905 - accuracy: 0.7714 - val_loss: 0.6006 - val_accuracy: 0.7079
# Epoch 31/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4898 - accuracy: 0.7701 - val_loss: 0.5876 - val_accuracy: 0.7127
# Epoch 32/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4860 - accuracy: 0.7840 - val_loss: 0.6580 - val_accuracy: 0.6565
# Epoch 33/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4840 - accuracy: 0.7779 - val_loss: 0.5525 - val_accuracy: 0.7400
# Epoch 34/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4973 - accuracy: 0.7697 - val_loss: 0.6159 - val_accuracy: 0.6822
# Epoch 35/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4928 - accuracy: 0.7738 - val_loss: 0.5695 - val_accuracy: 0.7335
# Epoch 36/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4886 - accuracy: 0.7779 - val_loss: 0.5661 - val_accuracy: 0.7352
# Epoch 37/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4925 - accuracy: 0.7766 - val_loss: 0.5681 - val_accuracy: 0.7335
# Epoch 38/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4915 - accuracy: 0.7734 - val_loss: 0.5574 - val_accuracy: 0.7608
# Epoch 39/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4818 - accuracy: 0.7852 - val_loss: 0.6109 - val_accuracy: 0.6726
# Epoch 40/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4933 - accuracy: 0.7742 - val_loss: 0.6123 - val_accuracy: 0.7095
# Epoch 41/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4818 - accuracy: 0.7836 - val_loss: 0.5615 - val_accuracy: 0.7416
# Epoch 42/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4873 - accuracy: 0.7799 - val_loss: 0.5527 - val_accuracy: 0.7512
# Epoch 43/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4759 - accuracy: 0.7880 - val_loss: 0.6391 - val_accuracy: 0.6629
# Epoch 44/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4932 - accuracy: 0.7693 - val_loss: 0.5765 - val_accuracy: 0.7143
# Epoch 45/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4907 - accuracy: 0.7714 - val_loss: 0.5832 - val_accuracy: 0.6998
# Epoch 46/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4842 - accuracy: 0.7811 - val_loss: 0.5706 - val_accuracy: 0.7223
# Epoch 47/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4840 - accuracy: 0.7836 - val_loss: 0.6733 - val_accuracy: 0.6260
# Epoch 48/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4862 - accuracy: 0.7832 - val_loss: 0.6009 - val_accuracy: 0.6645
# Epoch 49/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4993 - accuracy: 0.7697 - val_loss: 0.6284 - val_accuracy: 0.6806
# Epoch 50/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4932 - accuracy: 0.7791 - val_loss: 0.5749 - val_accuracy: 0.7384
# Epoch 51/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4892 - accuracy: 0.7750 - val_loss: 0.5380 - val_accuracy: 0.7464
# Epoch 52/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4862 - accuracy: 0.7750 - val_loss: 0.6221 - val_accuracy: 0.6934
# Epoch 53/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4827 - accuracy: 0.7787 - val_loss: 0.5634 - val_accuracy: 0.7319
# Epoch 54/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4748 - accuracy: 0.7954 - val_loss: 0.6236 - val_accuracy: 0.6838
# Epoch 55/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4909 - accuracy: 0.7787 - val_loss: 0.6388 - val_accuracy: 0.6661
# Epoch 56/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4817 - accuracy: 0.7840 - val_loss: 0.5988 - val_accuracy: 0.7175
# Epoch 57/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4830 - accuracy: 0.7840 - val_loss: 0.5615 - val_accuracy: 0.7255
# Epoch 58/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4874 - accuracy: 0.7811 - val_loss: 0.5888 - val_accuracy: 0.7095
# Epoch 59/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4778 - accuracy: 0.7876 - val_loss: 0.5508 - val_accuracy: 0.7271
# Epoch 60/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4892 - accuracy: 0.7803 - val_loss: 0.5675 - val_accuracy: 0.7384
# Epoch 61/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4897 - accuracy: 0.7823 - val_loss: 0.5921 - val_accuracy: 0.7014
# Epoch 62/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4813 - accuracy: 0.7880 - val_loss: 0.5694 - val_accuracy: 0.7175
# Epoch 63/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4785 - accuracy: 0.7823 - val_loss: 0.7365 - val_accuracy: 0.6180
# Epoch 64/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4840 - accuracy: 0.7823 - val_loss: 0.5910 - val_accuracy: 0.7111
# Epoch 65/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4778 - accuracy: 0.7815 - val_loss: 0.6087 - val_accuracy: 0.7014
# Epoch 66/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4876 - accuracy: 0.7803 - val_loss: 0.5785 - val_accuracy: 0.6998
# Epoch 67/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4743 - accuracy: 0.7889 - val_loss: 0.6093 - val_accuracy: 0.6966
# Epoch 68/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4870 - accuracy: 0.7779 - val_loss: 0.6582 - val_accuracy: 0.6437
# Epoch 69/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4780 - accuracy: 0.7872 - val_loss: 0.6046 - val_accuracy: 0.6966
# Epoch 70/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4829 - accuracy: 0.7860 - val_loss: 0.5659 - val_accuracy: 0.7223
# Epoch 71/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4903 - accuracy: 0.7754 - val_loss: 0.6367 - val_accuracy: 0.6629
# Epoch 72/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4706 - accuracy: 0.7905 - val_loss: 0.6151 - val_accuracy: 0.7047
# Epoch 73/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4777 - accuracy: 0.7868 - val_loss: 0.6541 - val_accuracy: 0.6726
# Epoch 74/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4773 - accuracy: 0.7815 - val_loss: 0.7804 - val_accuracy: 0.5778
# Epoch 75/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4764 - accuracy: 0.7872 - val_loss: 0.5561 - val_accuracy: 0.7480
# Epoch 76/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4780 - accuracy: 0.7893 - val_loss: 0.5911 - val_accuracy: 0.7175
# Epoch 77/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4738 - accuracy: 0.7929 - val_loss: 0.5507 - val_accuracy: 0.7287
# Epoch 78/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4875 - accuracy: 0.7856 - val_loss: 0.6761 - val_accuracy: 0.6276
# Epoch 79/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4777 - accuracy: 0.7893 - val_loss: 0.5649 - val_accuracy: 0.7464
# Epoch 80/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4750 - accuracy: 0.7872 - val_loss: 0.7101 - val_accuracy: 0.6324
# Epoch 81/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4843 - accuracy: 0.7828 - val_loss: 0.6186 - val_accuracy: 0.6950
# Epoch 82/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4737 - accuracy: 0.7921 - val_loss: 0.5558 - val_accuracy: 0.7512
# Epoch 83/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4767 - accuracy: 0.7950 - val_loss: 0.6102 - val_accuracy: 0.6934
# Epoch 84/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4850 - accuracy: 0.7864 - val_loss: 0.6473 - val_accuracy: 0.6581
# Epoch 85/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4714 - accuracy: 0.7823 - val_loss: 0.5522 - val_accuracy: 0.7544
# Epoch 86/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4782 - accuracy: 0.7848 - val_loss: 0.5646 - val_accuracy: 0.7448
# Epoch 87/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4750 - accuracy: 0.7828 - val_loss: 0.5653 - val_accuracy: 0.7239
# Epoch 88/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4717 - accuracy: 0.7872 - val_loss: 0.7533 - val_accuracy: 0.6613
# Epoch 89/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4765 - accuracy: 0.7913 - val_loss: 0.5422 - val_accuracy: 0.7640
# Epoch 90/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4760 - accuracy: 0.7872 - val_loss: 0.5664 - val_accuracy: 0.7303
# Epoch 91/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4822 - accuracy: 0.7836 - val_loss: 0.6135 - val_accuracy: 0.7030
# Epoch 92/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4843 - accuracy: 0.7860 - val_loss: 0.5669 - val_accuracy: 0.7319
# Epoch 93/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4804 - accuracy: 0.7828 - val_loss: 0.5848 - val_accuracy: 0.7143
# Epoch 94/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4732 - accuracy: 0.7876 - val_loss: 0.6402 - val_accuracy: 0.6485
# Epoch 95/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4761 - accuracy: 0.7868 - val_loss: 0.6308 - val_accuracy: 0.6854
# Epoch 96/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4726 - accuracy: 0.7897 - val_loss: 0.6069 - val_accuracy: 0.6838
# Epoch 97/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4734 - accuracy: 0.7860 - val_loss: 0.5518 - val_accuracy: 0.7480
# Epoch 98/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4703 - accuracy: 0.7970 - val_loss: 0.6510 - val_accuracy: 0.6437
# Epoch 99/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4694 - accuracy: 0.7913 - val_loss: 0.6106 - val_accuracy: 0.6934
# Epoch 100/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4737 - accuracy: 0.7852 - val_loss: 0.5873 - val_accuracy: 0.7095
# Epoch 101/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4729 - accuracy: 0.7868 - val_loss: 0.5848 - val_accuracy: 0.7223
# Epoch 102/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4713 - accuracy: 0.7840 - val_loss: 0.5454 - val_accuracy: 0.7480
# Epoch 103/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4675 - accuracy: 0.7986 - val_loss: 0.7449 - val_accuracy: 0.6308
# Epoch 104/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4708 - accuracy: 0.7962 - val_loss: 0.6495 - val_accuracy: 0.6838
# Epoch 105/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4701 - accuracy: 0.7889 - val_loss: 0.8261 - val_accuracy: 0.5859
# Epoch 106/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4883 - accuracy: 0.7742 - val_loss: 0.5693 - val_accuracy: 0.7271
# Epoch 107/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4729 - accuracy: 0.7897 - val_loss: 0.5711 - val_accuracy: 0.7335
# Epoch 108/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4739 - accuracy: 0.7872 - val_loss: 0.6042 - val_accuracy: 0.6934
# Epoch 109/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4613 - accuracy: 0.7970 - val_loss: 0.5542 - val_accuracy: 0.7480
# Epoch 110/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4610 - accuracy: 0.7990 - val_loss: 0.6081 - val_accuracy: 0.6982
# Epoch 111/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4709 - accuracy: 0.7852 - val_loss: 0.5755 - val_accuracy: 0.7111
# Epoch 112/200
# 308/308 [==============================] - 59s 190ms/step - loss: 0.4723 - accuracy: 0.7937 - val_loss: 0.5502 - val_accuracy: 0.7416
# Epoch 113/200
# 308/308 [==============================] - 59s 190ms/step - loss: 0.4763 - accuracy: 0.7893 - val_loss: 0.7069 - val_accuracy: 0.6597
# Epoch 114/200
# 308/308 [==============================] - 59s 190ms/step - loss: 0.4602 - accuracy: 0.7978 - val_loss: 0.6785 - val_accuracy: 0.6453
# Epoch 115/200
# 308/308 [==============================] - 59s 190ms/step - loss: 0.4724 - accuracy: 0.7950 - val_loss: 0.6136 - val_accuracy: 0.6950
# Epoch 116/200
# 308/308 [==============================] - 59s 190ms/step - loss: 0.4735 - accuracy: 0.7852 - val_loss: 0.6256 - val_accuracy: 0.6758
# Epoch 117/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4604 - accuracy: 0.8043 - val_loss: 0.6141 - val_accuracy: 0.6806
# Epoch 118/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4638 - accuracy: 0.7998 - val_loss: 0.6341 - val_accuracy: 0.6950
# Epoch 119/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4751 - accuracy: 0.7803 - val_loss: 0.6746 - val_accuracy: 0.6693
# Epoch 120/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4795 - accuracy: 0.7880 - val_loss: 0.5442 - val_accuracy: 0.7689
# Epoch 121/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4694 - accuracy: 0.7913 - val_loss: 0.5742 - val_accuracy: 0.7143
# Epoch 122/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4686 - accuracy: 0.7941 - val_loss: 0.6299 - val_accuracy: 0.6790
# Epoch 123/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4728 - accuracy: 0.7909 - val_loss: 0.5815 - val_accuracy: 0.7159
# Epoch 124/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4629 - accuracy: 0.7909 - val_loss: 0.5945 - val_accuracy: 0.7030
# Epoch 125/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4745 - accuracy: 0.7868 - val_loss: 0.6021 - val_accuracy: 0.7143
# Epoch 126/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4723 - accuracy: 0.7880 - val_loss: 0.5508 - val_accuracy: 0.7319
# Epoch 127/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4662 - accuracy: 0.7925 - val_loss: 0.7995 - val_accuracy: 0.5361
# Epoch 128/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4639 - accuracy: 0.7933 - val_loss: 0.7209 - val_accuracy: 0.6244
# Epoch 129/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4508 - accuracy: 0.8080 - val_loss: 0.6092 - val_accuracy: 0.7127
# Epoch 130/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4577 - accuracy: 0.8007 - val_loss: 0.6209 - val_accuracy: 0.6726
# Epoch 131/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4601 - accuracy: 0.7998 - val_loss: 0.6112 - val_accuracy: 0.6902
# Epoch 132/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4637 - accuracy: 0.7974 - val_loss: 0.6292 - val_accuracy: 0.6870
# Epoch 133/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4750 - accuracy: 0.7815 - val_loss: 0.5845 - val_accuracy: 0.7143
# Epoch 134/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4584 - accuracy: 0.7941 - val_loss: 0.5897 - val_accuracy: 0.7127
# Epoch 135/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4592 - accuracy: 0.7998 - val_loss: 0.6595 - val_accuracy: 0.6645
# Epoch 136/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4611 - accuracy: 0.8007 - val_loss: 0.5625 - val_accuracy: 0.7303
# Epoch 137/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4656 - accuracy: 0.8027 - val_loss: 0.6346 - val_accuracy: 0.6726
# Epoch 138/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4632 - accuracy: 0.7994 - val_loss: 0.6540 - val_accuracy: 0.6790
# Epoch 139/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4605 - accuracy: 0.7978 - val_loss: 0.6462 - val_accuracy: 0.6758
# Epoch 140/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4581 - accuracy: 0.8015 - val_loss: 0.5782 - val_accuracy: 0.7030
# Epoch 141/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4620 - accuracy: 0.7945 - val_loss: 0.5504 - val_accuracy: 0.7673
# Epoch 142/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4663 - accuracy: 0.7925 - val_loss: 0.5856 - val_accuracy: 0.7287
# Epoch 143/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4541 - accuracy: 0.8059 - val_loss: 0.5659 - val_accuracy: 0.7528
# Epoch 144/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4772 - accuracy: 0.7852 - val_loss: 0.5772 - val_accuracy: 0.7239
# Epoch 145/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4626 - accuracy: 0.7893 - val_loss: 0.5556 - val_accuracy: 0.7143
# Epoch 146/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4606 - accuracy: 0.8027 - val_loss: 0.5653 - val_accuracy: 0.7368
# Epoch 147/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4620 - accuracy: 0.7998 - val_loss: 0.5513 - val_accuracy: 0.7287
# Epoch 148/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4511 - accuracy: 0.8068 - val_loss: 0.6265 - val_accuracy: 0.6870
# Epoch 149/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4601 - accuracy: 0.8002 - val_loss: 0.5381 - val_accuracy: 0.7560
# Epoch 150/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4585 - accuracy: 0.8027 - val_loss: 0.5629 - val_accuracy: 0.7319
# Epoch 151/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4705 - accuracy: 0.7893 - val_loss: 0.6677 - val_accuracy: 0.6340
# Epoch 152/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4627 - accuracy: 0.8015 - val_loss: 0.5763 - val_accuracy: 0.7384
# Epoch 153/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4607 - accuracy: 0.7982 - val_loss: 0.5814 - val_accuracy: 0.7047
# Epoch 154/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4612 - accuracy: 0.7950 - val_loss: 0.5644 - val_accuracy: 0.7271
# Epoch 155/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4572 - accuracy: 0.7974 - val_loss: 0.5642 - val_accuracy: 0.7303
# Epoch 156/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4582 - accuracy: 0.8007 - val_loss: 0.5479 - val_accuracy: 0.7191
# Epoch 157/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4622 - accuracy: 0.7913 - val_loss: 0.5582 - val_accuracy: 0.7352
# Epoch 158/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4596 - accuracy: 0.7954 - val_loss: 0.5533 - val_accuracy: 0.7384
# Epoch 159/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4494 - accuracy: 0.8011 - val_loss: 0.5762 - val_accuracy: 0.7239
# Epoch 160/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4613 - accuracy: 0.7962 - val_loss: 0.5616 - val_accuracy: 0.7400
# Epoch 161/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4528 - accuracy: 0.8092 - val_loss: 0.5537 - val_accuracy: 0.7352
# Epoch 162/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4575 - accuracy: 0.7978 - val_loss: 0.7242 - val_accuracy: 0.6164
# Epoch 163/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4674 - accuracy: 0.7978 - val_loss: 0.7327 - val_accuracy: 0.6228
# Epoch 164/200
# 308/308 [==============================] - 59s 192ms/step - loss: 0.4592 - accuracy: 0.7994 - val_loss: 0.5641 - val_accuracy: 0.7400
# Epoch 165/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4553 - accuracy: 0.8011 - val_loss: 0.5565 - val_accuracy: 0.7608
# Epoch 166/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4581 - accuracy: 0.7990 - val_loss: 0.5503 - val_accuracy: 0.7448
# Epoch 167/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4555 - accuracy: 0.7986 - val_loss: 0.5475 - val_accuracy: 0.7384
# Epoch 168/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4588 - accuracy: 0.7978 - val_loss: 0.5887 - val_accuracy: 0.7143
# Epoch 169/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4573 - accuracy: 0.8007 - val_loss: 0.6602 - val_accuracy: 0.6822
# Epoch 170/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4621 - accuracy: 0.7962 - val_loss: 0.6605 - val_accuracy: 0.6613
# Epoch 171/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4531 - accuracy: 0.7978 - val_loss: 0.5566 - val_accuracy: 0.7384
# Epoch 172/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4503 - accuracy: 0.8023 - val_loss: 0.5684 - val_accuracy: 0.7335
# Epoch 173/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4628 - accuracy: 0.8002 - val_loss: 0.5816 - val_accuracy: 0.7271
# Epoch 174/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4576 - accuracy: 0.8023 - val_loss: 0.5918 - val_accuracy: 0.7175
# Epoch 175/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4629 - accuracy: 0.7893 - val_loss: 0.6579 - val_accuracy: 0.6822
# Epoch 176/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4674 - accuracy: 0.7937 - val_loss: 0.5667 - val_accuracy: 0.6998
# Epoch 177/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4642 - accuracy: 0.7950 - val_loss: 0.5388 - val_accuracy: 0.7480
# Epoch 178/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4566 - accuracy: 0.8019 - val_loss: 0.7098 - val_accuracy: 0.6244
# Epoch 179/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4550 - accuracy: 0.8039 - val_loss: 0.5665 - val_accuracy: 0.7207
# Epoch 180/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4529 - accuracy: 0.8031 - val_loss: 0.6248 - val_accuracy: 0.6966
# Epoch 181/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4511 - accuracy: 0.8112 - val_loss: 0.7340 - val_accuracy: 0.6196
# Epoch 182/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4487 - accuracy: 0.8076 - val_loss: 0.7528 - val_accuracy: 0.6276
# Epoch 183/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4501 - accuracy: 0.7998 - val_loss: 0.6644 - val_accuracy: 0.6693
# Epoch 184/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4525 - accuracy: 0.7974 - val_loss: 0.5784 - val_accuracy: 0.7239
# Epoch 185/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4473 - accuracy: 0.8100 - val_loss: 0.7080 - val_accuracy: 0.6356
# Epoch 186/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4408 - accuracy: 0.8124 - val_loss: 0.5677 - val_accuracy: 0.7239
# Epoch 187/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4585 - accuracy: 0.7978 - val_loss: 0.5558 - val_accuracy: 0.7400
# Epoch 188/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4513 - accuracy: 0.8080 - val_loss: 0.5477 - val_accuracy: 0.7624
# Epoch 189/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4537 - accuracy: 0.8096 - val_loss: 0.5690 - val_accuracy: 0.7191
# Epoch 190/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4530 - accuracy: 0.8076 - val_loss: 0.6426 - val_accuracy: 0.7030
# Epoch 191/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4390 - accuracy: 0.8177 - val_loss: 0.6981 - val_accuracy: 0.6469
# Epoch 192/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4526 - accuracy: 0.8035 - val_loss: 0.5532 - val_accuracy: 0.7464
# Epoch 193/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4439 - accuracy: 0.8112 - val_loss: 0.6393 - val_accuracy: 0.7030
# Epoch 194/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4534 - accuracy: 0.7958 - val_loss: 0.5490 - val_accuracy: 0.7416
# Epoch 195/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4484 - accuracy: 0.8051 - val_loss: 0.5741 - val_accuracy: 0.7432
# Epoch 196/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4421 - accuracy: 0.8039 - val_loss: 0.6540 - val_accuracy: 0.6645
# Epoch 197/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4448 - accuracy: 0.8088 - val_loss: 0.5512 - val_accuracy: 0.7319
# Epoch 198/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4493 - accuracy: 0.8039 - val_loss: 0.5598 - val_accuracy: 0.7416
# Epoch 199/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4425 - accuracy: 0.8108 - val_loss: 0.6102 - val_accuracy: 0.7030
# Epoch 200/200
# 308/308 [==============================] - 59s 191ms/step - loss: 0.4475 - accuracy: 0.8031 - val_loss: 0.5672 - val_accuracy: 0.7480

# %%
plot_graphs(history4, "accuracy")
plot_graphs(history4, "loss")

# %% [markdown]
# ## Save and load the model

# %%
resnet.save('saved_model/miniRes_model')
# Out:
# INFO:tensorflow:Assets written to: saved_model/miniRes_model/assets

# %%
resnet.save_weights('saved_model/miniRes_weights')

# %%
loaded_model = ResNet(1)

# %%
loaded_model.load_weights('saved_model/miniRes_weights')

# %%
loaded_model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.0001),
               loss=tf.keras.losses.BinaryCrossentropy(),
               metrics=['accuracy'])

# %%
loss,acc = loaded_model.evaluate(test_generator, verbose=2)
# Out:
# 39/39 - 4s - loss: 0.5672 - accuracy: 0.7480

# %%
# delete the data

shutil.rmtree('/tmp/Liver_'+equipment)

# %%
import os, signal
train_generator, test_generator
os.kill(os.getpid(),signal.SIGKILL)
