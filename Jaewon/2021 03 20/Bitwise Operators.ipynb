# %% [markdown]
# ## Bitwise Operators

# %%
import numpy as np, cv2
import matplotlib.pyplot as plt

img1 = np.zeros((200,400))
img2 = np.zeros((200,400))
img1[:, :200] = 255         # Left White(255), Right black(0)
img2[100:200, :] = 255      # Up Black(0), Down White(255)

# Bitwise Operators
bitAnd = cv2.bitwise_and(img1, img2)
bitOr = cv2.bitwise_or(img1, img2)
bitXor = cv2.bitwise_xor(img1, img2)
bitNot = cv2.bitwise_not(img1)

# Plot
imgs = {'img1':img1, 'img2':img2, 'and':bitAnd, 
          'or':bitOr, 'xor':bitXor, 'not(img1)':bitNot}
for i, (title, img) in enumerate(imgs.items()):
    plt.subplot(3,2,i+1)
    plt.title(title)
    plt.imshow(img, 'gray')
    plt.xticks([]); plt.yticks([])

plt.show()

# %% [markdown]
# ## Training Data

# %%
path = '../../../Data/Liver_png/'

# %%
img = cv2.imread(path+'0001/mask/00010001.png')
img_mask = cv2.imread(path+'0001/mask/00010001_mask.png')
img_masked = cv2.bitwise_and(img, img_mask)

# %%
imgs = {'img':img, 'img_mask':img_mask,
        'masked':img_masked}
for i, (title, img) in enumerate(imgs.items()):
    plt.figure(figsize=(10,10))
    plt.title(title)
    plt.imshow(img, 'gray')

# %%
print(cv2.__version__)
# Out:
# 3.4.5
