# %%
# 300x400
# Fibrosis level 0 vs 4
# drop 0.2

# %%
import pandas as pd
import numpy as np


import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator 

import zipfile
import os
import shutil
import random

# %%
data = pd.read_csv("data.csv")
data.Fibrosis = data.Fibrosis.replace('-', np.NaN)
data.Equipment.value_counts()
# Out:
# IU22        101
# LOGIQE9      99
# iu22         78
# EUB-7500     70
# eub-7500     45
# S2000        28
# s2000         5
# Name: Equipment, dtype: int64

# %%
# to upper character

# data['Equipment'] = data['Equipment'].apply(lambda x: x.upper())

# %%
data['Equipment'] = 'M'

# %%
def sort_by_equipment(equipment):
    return data[(data['Equipment'] == equipment)]['Fibrosis'].value_counts()

# %%
data.Fibrosis = pd.to_numeric(data.Fibrosis)

# %%
# divide the data by Equipment

def fill_zero(f):
    for i in range(len(f)):
        f[i] = f[i].zfill(4)
    
    return f

def sort_by_tool(equipment):
    f_neg = data[(data['Fibrosis']==0) & (data['Equipment']==equipment.upper())].number.astype(str).tolist()
    f_pos = data[(data['Fibrosis']==4) & (data['Equipment']==equipment.upper())].number.astype(str).tolist()
    ################ change the Fibrosis level from here #####################
    
    
    
    # fill the zeros (for foloder name)
    f_neg = fill_zero(f_neg)
    f_pos = fill_zero(f_pos)
    
    return f_neg, f_pos


def move_to_tmp(local_zip, equipment, base_loc):
    zip_ref = zipfile.ZipFile(local_zip, 'r')
    zip_ref.extractall('/tmp/Liver_'+equipment)
    zip_ref.close()

def make_folder(base_loc):
    try:
        os.mkdir(base_loc)
        os.mkdir(base_loc+'/training')
        os.mkdir(base_loc+'/training/f0')
        os.mkdir(base_loc+'/training/f1')
        os.mkdir(base_loc+'/testing')
        os.mkdir(base_loc+'/testing/f0')
        os.mkdir(base_loc+'/testing/f1')

    except OSError:
        pass

def move_to_folder(f_, folder_loc, split, base_loc):
    split = int(len(f_)*(1-split))
    
    f_train = f_[:split]
    f_test = f_[split:]
    
    print(folder_loc,':',len(f_train))
    print(folder_loc,':',len(f_test))
    
    new_name = 0
    for folder_name in f_train:
        for root, subdirs, files in os.walk(base_loc+'/'+folder_name):
            for f in files:
                # file_name change
                try:
                    file_to_change = os.path.join(root, f)
                    dst = str(new_name)+'.tif'
                    dst = os.path.join(root, dst)
                    # print(file_to_change, new_name)

                    os.rename(file_to_change, dst)
                    new_name += 1
                    tmp = base_loc+'/training/'+folder_loc
                    # file move
                    shutil.move(dst, tmp)
                except:
                    print('error')
    
    new_name = 0                    
    for folder_name in f_test:
        for root, subdirs, files in os.walk(base_loc+'/'+folder_name):
            for f in files:
                # file_name change
                try:
                    file_to_change = os.path.join(root, f)
                    dst = str(new_name)+'.tif'
                    # print(file_to_change, new_name)

                    dst = os.path.join(root, dst)
                    os.rename(file_to_change, dst)
                    new_name += 1
                    tmp = base_loc+'/testing/'+folder_loc
                    # file move
                    shutil.move(dst, tmp)
                except:
                    print('error')

# %%
def train_test_split(equipment, local_zip, split_size):
    equipment = equipment.upper()
    f_false, f_true = sort_by_tool(equipment)
    
    random.shuffle(f_false)
    random.shuffle(f_true)
    
    make_folder(base_loc)
    move_to_tmp(local_zip, equipment, base_loc)
    
    move_to_folder(f_false, 'f0', 0.2, base_loc)
    move_to_folder(f_true, 'f1', 0.2, base_loc)

# %%
def ImageGenerator(base_loc):
    TRAINING_DIR = base_loc+'/training'
    train_datagen = ImageDataGenerator(rescale = 1./255.)

    train_generator = train_datagen.flow_from_directory(TRAINING_DIR,
                                                       batch_size=8,
                                                       class_mode='binary',
                                                       target_size=(300,400),
                                                       color_mode='grayscale') # target_size = (height, width)

    TESTING_DIR = base_loc+'/testing'
    test_datagen = ImageDataGenerator(rescale = 1.0/255.)

    test_generator = train_datagen.flow_from_directory(TESTING_DIR,
                                                       batch_size=16,
                                                       class_mode='binary',
                                                       target_size=(300,400), 
                                                       color_mode='grayscale')
    
    return train_generator, test_generator

# %%
# change
equipment = 'M' 
local_zip = '../../../Data/300_400.zip'
base_loc = '/tmp/Liver_' + equipment

# %%
train_test_split(equipment, local_zip, 0.2)
# Out:
# f0 : 116
# f0 : 30
# f1 : 118
# f1 : 30

# %%
# training

# error files:
# 1881/mask/1881-0006.tif
# 1813/mask/1813-0002.tif
# 2103/mask/2013-0001.tif

# %%
print("Training Fibrosis 0:", len(os.listdir(base_loc+'/training/f0')))
print("Testing Fibrosis 0:", len(os.listdir(base_loc+'/testing/f0')))
print("-"*25)
print("Training Fibrosis 1:", len(os.listdir(base_loc+'/training/f1')))
print("Testing Fibrosis 1:", len(os.listdir(base_loc+'/testing/f1')))
# Out:
# Training Fibrosis 0: 890
# Testing Fibrosis 0: 219
# -------------------------
# Training Fibrosis 1: 746
# Testing Fibrosis 1: 165

# %%
train_generator, test_generator = ImageGenerator(base_loc)
# Out:
# Found 1636 images belonging to 2 classes.
# Found 384 images belonging to 2 classes.

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
            logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# ## Simple Res Model

# %%
from tensorflow.keras.layers import Layer

# %%
class IdentityBlock(tf.keras.Model):
    def __init__(self, filters, kernel_size):
        super(IdentityBlock, self).__init__(name='')
        
        self.conv1 = tf.keras.layers.Conv2D(filters, kernel_size, padding='same')
        self.bn1 = tf.keras.layers.BatchNormalization()
        
        self.conv2 = tf.keras.layers.Conv2D(filters, kernel_size, padding='same')
        self.bn2 = tf.keras.layers.BatchNormalization()
        
        self.act = tf.keras.layers.Activation('relu')
        self.add = tf.keras.layers.Add()
        
    def call(self, input_tensor):
        X = self.conv1(input_tensor)
        X = self.bn1(X)
        X = self.act(X)
        
        X = self.conv2(X)
        X = self.bn2(X)
        
        X = self.add([X, input_tensor])
        X = self.act(X)
        return X
    
class ResNet(tf.keras.Model):
    def __init__(self, num_classes):
        super(ResNet, self).__init__()
        self.conv = tf.keras.layers.Conv2D(64, 7, padding='same')
        self.bn = tf.keras.layers.BatchNormalization()
        self.act = tf.keras.layers.Activation('relu')
        self.max_pool = tf.keras.layers.MaxPool2D((3, 3))

        # Use the Identity blocks that you just defined
        self.id1a = IdentityBlock(64, 3)
        self.id1b = IdentityBlock(64, 3)

        self.global_pool = tf.keras.layers.GlobalAveragePooling2D()
        
        self.flatten = tf.keras.layers.Flatten()
        self.drop = tf.keras.layers.Dropout(0.2)
        self.dense_1 = tf.keras.layers.Dense(1024, activation='sigmoid')
        self.dense_2 = tf.keras.layers.Dense(512, activation='sigmoid')
        self.classifier = tf.keras.layers.Dense(num_classes, activation='sigmoid')

    def call(self, inputs):
        x = self.conv(inputs)
        x = self.bn(x)
        x = self.act(x)
        x = self.max_pool(x)

        # insert the identity blocks in the middle of the network
        x = self.id1a(x)
        x = self.id1b(x)
        x = self.global_pool(x)
        
        x = self.flatten(x)
        x = self.drop(x)
        x = self.dense_1(x)
        x = self.dense_2(x)
        
        return self.classifier(x)

# %%
resnet = ResNet(1)

# %%
resnet.compile(optimizer=tf.keras.optimizers.Adam(lr=0.0001),
               loss=tf.keras.losses.BinaryCrossentropy(),
               metrics=['accuracy'])

# %%
history = resnet.fit(train_generator,
           epochs=100,
           validation_data=test_generator)
# Out:
# Epoch 1/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.6856 - accuracy: 0.5513 - val_loss: 0.9114 - val_accuracy: 0.5703
# Epoch 2/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.6579 - accuracy: 0.5954 - val_loss: 1.8415 - val_accuracy: 0.5703
# Epoch 3/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.6310 - accuracy: 0.6394 - val_loss: 1.2193 - val_accuracy: 0.5703
# Epoch 4/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.6268 - accuracy: 0.6516 - val_loss: 0.7638 - val_accuracy: 0.6172
# Epoch 5/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.6176 - accuracy: 0.6577 - val_loss: 0.6556 - val_accuracy: 0.6120
# Epoch 6/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.6021 - accuracy: 0.6656 - val_loss: 0.6589 - val_accuracy: 0.6224
# Epoch 7/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.5964 - accuracy: 0.6889 - val_loss: 0.9025 - val_accuracy: 0.4688
# Epoch 8/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.6001 - accuracy: 0.6785 - val_loss: 0.7628 - val_accuracy: 0.5469
# Epoch 9/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.5906 - accuracy: 0.6681 - val_loss: 1.0928 - val_accuracy: 0.4740
# Epoch 10/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.5730 - accuracy: 0.7066 - val_loss: 0.7677 - val_accuracy: 0.6172
# Epoch 11/100
# 205/205 [==============================] - 8s 41ms/step - loss: 0.5725 - accuracy: 0.6974 - val_loss: 0.7629 - val_accuracy: 0.5755
# Epoch 12/100
# 205/205 [==============================] - 8s 41ms/step - loss: 0.5773 - accuracy: 0.6962 - val_loss: 0.7017 - val_accuracy: 0.6094
# Epoch 13/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.5572 - accuracy: 0.7139 - val_loss: 0.6278 - val_accuracy: 0.6510
# Epoch 14/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.5407 - accuracy: 0.7243 - val_loss: 1.5226 - val_accuracy: 0.4531
# Epoch 15/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.5506 - accuracy: 0.7219 - val_loss: 0.5892 - val_accuracy: 0.6641
# Epoch 16/100
# 205/205 [==============================] - 8s 41ms/step - loss: 0.5419 - accuracy: 0.7170 - val_loss: 0.6070 - val_accuracy: 0.6667
# Epoch 17/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.5314 - accuracy: 0.7207 - val_loss: 0.8614 - val_accuracy: 0.5339
# Epoch 18/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.5368 - accuracy: 0.7317 - val_loss: 0.6344 - val_accuracy: 0.6589
# Epoch 19/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.5263 - accuracy: 0.7366 - val_loss: 0.5701 - val_accuracy: 0.6875
# Epoch 20/100
# 205/205 [==============================] - 9s 41ms/step - loss: 0.5189 - accuracy: 0.7372 - val_loss: 0.6726 - val_accuracy: 0.6432
# Epoch 21/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.5217 - accuracy: 0.7463 - val_loss: 0.5878 - val_accuracy: 0.6823
# Epoch 22/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.5370 - accuracy: 0.7225 - val_loss: 0.5864 - val_accuracy: 0.6771
# Epoch 23/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.5289 - accuracy: 0.7359 - val_loss: 0.8651 - val_accuracy: 0.5833
# Epoch 24/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.5046 - accuracy: 0.7384 - val_loss: 0.7297 - val_accuracy: 0.6406
# Epoch 25/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.5073 - accuracy: 0.7457 - val_loss: 0.6862 - val_accuracy: 0.6589
# Epoch 26/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.5085 - accuracy: 0.7323 - val_loss: 0.5881 - val_accuracy: 0.6667
# Epoch 27/100
# 205/205 [==============================] - 8s 41ms/step - loss: 0.5091 - accuracy: 0.7469 - val_loss: 1.9148 - val_accuracy: 0.5703
# Epoch 28/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.5058 - accuracy: 0.7482 - val_loss: 0.5705 - val_accuracy: 0.7109
# Epoch 29/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4982 - accuracy: 0.7641 - val_loss: 0.5386 - val_accuracy: 0.7240
# Epoch 30/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4963 - accuracy: 0.7622 - val_loss: 0.6091 - val_accuracy: 0.6953
# Epoch 31/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.5056 - accuracy: 0.7549 - val_loss: 0.5534 - val_accuracy: 0.6875
# Epoch 32/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4970 - accuracy: 0.7476 - val_loss: 0.4877 - val_accuracy: 0.7578
# Epoch 33/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4947 - accuracy: 0.7537 - val_loss: 2.1315 - val_accuracy: 0.4297
# Epoch 34/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4902 - accuracy: 0.7714 - val_loss: 0.5204 - val_accuracy: 0.7266
# Epoch 35/100
# 205/205 [==============================] - 8s 41ms/step - loss: 0.4869 - accuracy: 0.7641 - val_loss: 1.3010 - val_accuracy: 0.5365
# Epoch 36/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4923 - accuracy: 0.7549 - val_loss: 2.2707 - val_accuracy: 0.5703
# Epoch 37/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4891 - accuracy: 0.7628 - val_loss: 0.5799 - val_accuracy: 0.7135
# Epoch 38/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4976 - accuracy: 0.7518 - val_loss: 0.5538 - val_accuracy: 0.7161
# Epoch 39/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4726 - accuracy: 0.7677 - val_loss: 0.6644 - val_accuracy: 0.6797
# Epoch 40/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4752 - accuracy: 0.7683 - val_loss: 0.5219 - val_accuracy: 0.7396
# Epoch 41/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4797 - accuracy: 0.7659 - val_loss: 2.2892 - val_accuracy: 0.5703
# Epoch 42/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4500 - accuracy: 0.7775 - val_loss: 0.5497 - val_accuracy: 0.7109
# Epoch 43/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4666 - accuracy: 0.7787 - val_loss: 0.4584 - val_accuracy: 0.7630
# Epoch 44/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4882 - accuracy: 0.7622 - val_loss: 0.5417 - val_accuracy: 0.7188
# Epoch 45/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4732 - accuracy: 0.7763 - val_loss: 0.5311 - val_accuracy: 0.7500
# Epoch 46/100
# 205/205 [==============================] - 8s 41ms/step - loss: 0.4633 - accuracy: 0.7787 - val_loss: 0.4981 - val_accuracy: 0.7682
# Epoch 47/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4717 - accuracy: 0.7738 - val_loss: 0.4871 - val_accuracy: 0.7708
# Epoch 48/100
# 205/205 [==============================] - 8s 41ms/step - loss: 0.4755 - accuracy: 0.7683 - val_loss: 0.5327 - val_accuracy: 0.7135
# Epoch 49/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4564 - accuracy: 0.7775 - val_loss: 1.2452 - val_accuracy: 0.5234
# Epoch 50/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4605 - accuracy: 0.7867 - val_loss: 0.5236 - val_accuracy: 0.7292
# Epoch 51/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4654 - accuracy: 0.7726 - val_loss: 0.7142 - val_accuracy: 0.6849
# Epoch 52/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4585 - accuracy: 0.7885 - val_loss: 0.4923 - val_accuracy: 0.7500
# Epoch 53/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4531 - accuracy: 0.7910 - val_loss: 0.5444 - val_accuracy: 0.6979
# Epoch 54/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4398 - accuracy: 0.7946 - val_loss: 0.6134 - val_accuracy: 0.7292
# Epoch 55/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4584 - accuracy: 0.7732 - val_loss: 1.3260 - val_accuracy: 0.5755
# Epoch 56/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4462 - accuracy: 0.7910 - val_loss: 1.0062 - val_accuracy: 0.5703
# Epoch 57/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4677 - accuracy: 0.7769 - val_loss: 0.6246 - val_accuracy: 0.7188
# Epoch 58/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4439 - accuracy: 0.7897 - val_loss: 0.5702 - val_accuracy: 0.7240
# Epoch 59/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4446 - accuracy: 0.8026 - val_loss: 0.5527 - val_accuracy: 0.7344
# Epoch 60/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4435 - accuracy: 0.7995 - val_loss: 0.5345 - val_accuracy: 0.7370
# Epoch 61/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4342 - accuracy: 0.8032 - val_loss: 0.5838 - val_accuracy: 0.7318
# Epoch 62/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4205 - accuracy: 0.8032 - val_loss: 0.5742 - val_accuracy: 0.7188
# Epoch 63/100
# 205/205 [==============================] - 8s 41ms/step - loss: 0.4258 - accuracy: 0.8093 - val_loss: 0.5827 - val_accuracy: 0.7240
# Epoch 64/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4338 - accuracy: 0.7848 - val_loss: 0.4942 - val_accuracy: 0.7578
# Epoch 65/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4442 - accuracy: 0.7977 - val_loss: 0.6502 - val_accuracy: 0.6901
# Epoch 66/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4312 - accuracy: 0.8007 - val_loss: 1.3230 - val_accuracy: 0.5156
# Epoch 67/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4471 - accuracy: 0.7903 - val_loss: 0.8396 - val_accuracy: 0.6615
# Epoch 68/100
# 205/205 [==============================] - 8s 41ms/step - loss: 0.4361 - accuracy: 0.7934 - val_loss: 0.4832 - val_accuracy: 0.7656
# Epoch 69/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4374 - accuracy: 0.7934 - val_loss: 1.1150 - val_accuracy: 0.6094
# Epoch 70/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4214 - accuracy: 0.8160 - val_loss: 0.9926 - val_accuracy: 0.5938
# Epoch 71/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4277 - accuracy: 0.8087 - val_loss: 0.4491 - val_accuracy: 0.7812
# Epoch 72/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4142 - accuracy: 0.8178 - val_loss: 0.5214 - val_accuracy: 0.7526
# Epoch 73/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4000 - accuracy: 0.8123 - val_loss: 2.5848 - val_accuracy: 0.5703
# Epoch 74/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4408 - accuracy: 0.7897 - val_loss: 1.9154 - val_accuracy: 0.4323
# Epoch 75/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4291 - accuracy: 0.7928 - val_loss: 0.9477 - val_accuracy: 0.5938
# Epoch 76/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3996 - accuracy: 0.8191 - val_loss: 1.5803 - val_accuracy: 0.5807
# Epoch 77/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3943 - accuracy: 0.8240 - val_loss: 0.7139 - val_accuracy: 0.7109
# Epoch 78/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4108 - accuracy: 0.8227 - val_loss: 0.4684 - val_accuracy: 0.7786
# Epoch 79/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4171 - accuracy: 0.8123 - val_loss: 2.2985 - val_accuracy: 0.5729
# Epoch 80/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4096 - accuracy: 0.8142 - val_loss: 0.6192 - val_accuracy: 0.7318
# Epoch 81/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3980 - accuracy: 0.8142 - val_loss: 2.0220 - val_accuracy: 0.4609
# Epoch 82/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4195 - accuracy: 0.8117 - val_loss: 0.4505 - val_accuracy: 0.7839
# Epoch 83/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4018 - accuracy: 0.8203 - val_loss: 0.9895 - val_accuracy: 0.6380
# Epoch 84/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4023 - accuracy: 0.8154 - val_loss: 2.6195 - val_accuracy: 0.5703
# Epoch 85/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4364 - accuracy: 0.7952 - val_loss: 0.4485 - val_accuracy: 0.7812
# Epoch 86/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4177 - accuracy: 0.8136 - val_loss: 0.4801 - val_accuracy: 0.7578
# Epoch 87/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4052 - accuracy: 0.8191 - val_loss: 1.3823 - val_accuracy: 0.5052
# Epoch 88/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4283 - accuracy: 0.8032 - val_loss: 0.4803 - val_accuracy: 0.7656
# Epoch 89/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4092 - accuracy: 0.8038 - val_loss: 0.5334 - val_accuracy: 0.7318
# Epoch 90/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4040 - accuracy: 0.8197 - val_loss: 0.6977 - val_accuracy: 0.6641
# Epoch 91/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3962 - accuracy: 0.8209 - val_loss: 0.5596 - val_accuracy: 0.7344
# Epoch 92/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3903 - accuracy: 0.8221 - val_loss: 1.0427 - val_accuracy: 0.5755
# Epoch 93/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3992 - accuracy: 0.8178 - val_loss: 2.8358 - val_accuracy: 0.5703
# Epoch 94/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4180 - accuracy: 0.8117 - val_loss: 0.5663 - val_accuracy: 0.7526
# Epoch 95/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3797 - accuracy: 0.8368 - val_loss: 0.7263 - val_accuracy: 0.6823
# Epoch 96/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4050 - accuracy: 0.8166 - val_loss: 0.5860 - val_accuracy: 0.7396
# Epoch 97/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3933 - accuracy: 0.8270 - val_loss: 0.5554 - val_accuracy: 0.7344
# Epoch 98/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3771 - accuracy: 0.8331 - val_loss: 0.7801 - val_accuracy: 0.6693
# Epoch 99/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3900 - accuracy: 0.8374 - val_loss: 1.0566 - val_accuracy: 0.6250
# Epoch 100/100
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3932 - accuracy: 0.8325 - val_loss: 0.4689 - val_accuracy: 0.7969

# %%
import matplotlib.pyplot as plt

def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()
    
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %%
history2 = resnet.fit(train_generator,
           epochs=200,
           validation_data=test_generator)
# Out:
# Epoch 1/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3722 - accuracy: 0.8399 - val_loss: 0.4599 - val_accuracy: 0.7786
# Epoch 2/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3669 - accuracy: 0.8399 - val_loss: 0.8030 - val_accuracy: 0.7005
# Epoch 3/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3739 - accuracy: 0.8435 - val_loss: 0.9994 - val_accuracy: 0.6120
# Epoch 4/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.4027 - accuracy: 0.8227 - val_loss: 0.4872 - val_accuracy: 0.7760
# Epoch 5/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3900 - accuracy: 0.8295 - val_loss: 1.2517 - val_accuracy: 0.5807
# Epoch 6/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3873 - accuracy: 0.8227 - val_loss: 0.5875 - val_accuracy: 0.7266
# Epoch 7/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3599 - accuracy: 0.8386 - val_loss: 1.3966 - val_accuracy: 0.5964
# Epoch 8/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3700 - accuracy: 0.8423 - val_loss: 0.6521 - val_accuracy: 0.7396
# Epoch 9/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3698 - accuracy: 0.8282 - val_loss: 1.3996 - val_accuracy: 0.5130
# Epoch 10/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3782 - accuracy: 0.8282 - val_loss: 1.9617 - val_accuracy: 0.4792
# Epoch 11/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3703 - accuracy: 0.8307 - val_loss: 0.5668 - val_accuracy: 0.6979
# Epoch 12/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3609 - accuracy: 0.8362 - val_loss: 0.5703 - val_accuracy: 0.7474
# Epoch 13/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3737 - accuracy: 0.8344 - val_loss: 0.8700 - val_accuracy: 0.6432
# Epoch 14/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3632 - accuracy: 0.8344 - val_loss: 0.4717 - val_accuracy: 0.7786
# Epoch 15/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3535 - accuracy: 0.8454 - val_loss: 0.8877 - val_accuracy: 0.6068
# Epoch 16/200
# 205/205 [==============================] - 8s 41ms/step - loss: 0.3723 - accuracy: 0.8454 - val_loss: 1.4396 - val_accuracy: 0.5781
# Epoch 17/200
# 205/205 [==============================] - 8s 41ms/step - loss: 0.3563 - accuracy: 0.8411 - val_loss: 0.4581 - val_accuracy: 0.7891
# Epoch 18/200
# 205/205 [==============================] - 8s 41ms/step - loss: 0.3444 - accuracy: 0.8612 - val_loss: 1.1309 - val_accuracy: 0.5755
# Epoch 19/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3697 - accuracy: 0.8380 - val_loss: 0.5892 - val_accuracy: 0.7396
# Epoch 20/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3722 - accuracy: 0.8405 - val_loss: 1.2041 - val_accuracy: 0.5964
# Epoch 21/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3578 - accuracy: 0.8350 - val_loss: 0.6914 - val_accuracy: 0.6979
# Epoch 22/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3938 - accuracy: 0.8264 - val_loss: 2.1710 - val_accuracy: 0.5807
# Epoch 23/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3468 - accuracy: 0.8478 - val_loss: 0.5263 - val_accuracy: 0.7708
# Epoch 24/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3719 - accuracy: 0.8447 - val_loss: 0.6435 - val_accuracy: 0.7344
# Epoch 25/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3645 - accuracy: 0.8307 - val_loss: 1.6547 - val_accuracy: 0.5807
# Epoch 26/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3522 - accuracy: 0.8509 - val_loss: 0.4513 - val_accuracy: 0.8125
# Epoch 27/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3601 - accuracy: 0.8447 - val_loss: 0.4765 - val_accuracy: 0.8047
# Epoch 28/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3373 - accuracy: 0.8564 - val_loss: 1.0213 - val_accuracy: 0.6224
# Epoch 29/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3497 - accuracy: 0.8527 - val_loss: 1.1352 - val_accuracy: 0.5938
# Epoch 30/200
# 205/205 [==============================] - 8s 41ms/step - loss: 0.3616 - accuracy: 0.8386 - val_loss: 1.3962 - val_accuracy: 0.5885
# Epoch 31/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3319 - accuracy: 0.8631 - val_loss: 0.9811 - val_accuracy: 0.5938
# Epoch 32/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3519 - accuracy: 0.8496 - val_loss: 0.8223 - val_accuracy: 0.6719
# Epoch 33/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3408 - accuracy: 0.8509 - val_loss: 0.4711 - val_accuracy: 0.7839
# Epoch 34/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3592 - accuracy: 0.8490 - val_loss: 0.6587 - val_accuracy: 0.7240
# Epoch 35/200
# 205/205 [==============================] - 8s 41ms/step - loss: 0.3315 - accuracy: 0.8533 - val_loss: 0.4938 - val_accuracy: 0.7839
# Epoch 36/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3305 - accuracy: 0.8502 - val_loss: 2.7341 - val_accuracy: 0.4479
# Epoch 37/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3545 - accuracy: 0.8496 - val_loss: 0.5835 - val_accuracy: 0.7552
# Epoch 38/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2971 - accuracy: 0.8851 - val_loss: 0.4560 - val_accuracy: 0.7708
# Epoch 39/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3235 - accuracy: 0.8576 - val_loss: 1.3157 - val_accuracy: 0.5755
# Epoch 40/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3347 - accuracy: 0.8619 - val_loss: 0.5001 - val_accuracy: 0.7682
# Epoch 41/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3280 - accuracy: 0.8582 - val_loss: 1.1621 - val_accuracy: 0.6302
# Epoch 42/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3318 - accuracy: 0.8606 - val_loss: 0.6910 - val_accuracy: 0.6901
# Epoch 43/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3314 - accuracy: 0.8582 - val_loss: 0.5745 - val_accuracy: 0.7734
# Epoch 44/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3333 - accuracy: 0.8588 - val_loss: 0.4350 - val_accuracy: 0.8073
# Epoch 45/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3328 - accuracy: 0.8612 - val_loss: 1.6600 - val_accuracy: 0.4635
# Epoch 46/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3365 - accuracy: 0.8570 - val_loss: 1.2121 - val_accuracy: 0.5911
# Epoch 47/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3304 - accuracy: 0.8606 - val_loss: 2.2865 - val_accuracy: 0.5781
# Epoch 48/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3376 - accuracy: 0.8551 - val_loss: 1.0936 - val_accuracy: 0.5911
# Epoch 49/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3266 - accuracy: 0.8545 - val_loss: 0.5637 - val_accuracy: 0.7682
# Epoch 50/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3198 - accuracy: 0.8576 - val_loss: 0.5495 - val_accuracy: 0.7448
# Epoch 51/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3277 - accuracy: 0.8625 - val_loss: 0.7735 - val_accuracy: 0.6901
# Epoch 52/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3168 - accuracy: 0.8643 - val_loss: 1.3054 - val_accuracy: 0.5807
# Epoch 53/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3170 - accuracy: 0.8649 - val_loss: 0.4568 - val_accuracy: 0.7708
# Epoch 54/200
# 205/205 [==============================] - 8s 41ms/step - loss: 0.3058 - accuracy: 0.8710 - val_loss: 0.9021 - val_accuracy: 0.6823
# Epoch 55/200
# 205/205 [==============================] - 8s 41ms/step - loss: 0.3054 - accuracy: 0.8710 - val_loss: 1.5006 - val_accuracy: 0.6042
# Epoch 56/200
# 205/205 [==============================] - 8s 41ms/step - loss: 0.3256 - accuracy: 0.8655 - val_loss: 0.6210 - val_accuracy: 0.7083
# Epoch 57/200
# 205/205 [==============================] - 8s 41ms/step - loss: 0.2978 - accuracy: 0.8790 - val_loss: 0.4918 - val_accuracy: 0.7891
# Epoch 58/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3109 - accuracy: 0.8612 - val_loss: 1.0383 - val_accuracy: 0.6615
# Epoch 59/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3090 - accuracy: 0.8771 - val_loss: 0.4457 - val_accuracy: 0.7812
# Epoch 60/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3320 - accuracy: 0.8631 - val_loss: 1.1064 - val_accuracy: 0.6458
# Epoch 61/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3168 - accuracy: 0.8643 - val_loss: 0.6572 - val_accuracy: 0.7448
# Epoch 62/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3137 - accuracy: 0.8649 - val_loss: 1.8796 - val_accuracy: 0.5781
# Epoch 63/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3038 - accuracy: 0.8661 - val_loss: 1.0552 - val_accuracy: 0.6146
# Epoch 64/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3097 - accuracy: 0.8674 - val_loss: 0.4311 - val_accuracy: 0.8125
# Epoch 65/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2922 - accuracy: 0.8796 - val_loss: 0.4293 - val_accuracy: 0.8333
# Epoch 66/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3177 - accuracy: 0.8631 - val_loss: 0.4754 - val_accuracy: 0.7865
# Epoch 67/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2790 - accuracy: 0.8863 - val_loss: 1.0443 - val_accuracy: 0.5964
# Epoch 68/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3401 - accuracy: 0.8582 - val_loss: 3.3036 - val_accuracy: 0.5703
# Epoch 69/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3114 - accuracy: 0.8649 - val_loss: 1.0610 - val_accuracy: 0.6406
# Epoch 70/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2909 - accuracy: 0.8759 - val_loss: 1.0170 - val_accuracy: 0.6224
# Epoch 71/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2923 - accuracy: 0.8747 - val_loss: 1.0023 - val_accuracy: 0.6276
# Epoch 72/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2954 - accuracy: 0.8741 - val_loss: 0.5681 - val_accuracy: 0.7526
# Epoch 73/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3194 - accuracy: 0.8655 - val_loss: 1.0219 - val_accuracy: 0.6667
# Epoch 74/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2803 - accuracy: 0.8845 - val_loss: 1.1188 - val_accuracy: 0.6302
# Epoch 75/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2864 - accuracy: 0.8771 - val_loss: 0.9926 - val_accuracy: 0.6432
# Epoch 76/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2950 - accuracy: 0.8716 - val_loss: 2.0097 - val_accuracy: 0.5703
# Epoch 77/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2926 - accuracy: 0.8765 - val_loss: 0.6813 - val_accuracy: 0.7474
# Epoch 78/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2927 - accuracy: 0.8796 - val_loss: 1.3914 - val_accuracy: 0.6042
# Epoch 79/200
# 205/205 [==============================] - 8s 41ms/step - loss: 0.2931 - accuracy: 0.8729 - val_loss: 1.8275 - val_accuracy: 0.5938
# Epoch 80/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2801 - accuracy: 0.8881 - val_loss: 0.5239 - val_accuracy: 0.7917
# Epoch 81/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2914 - accuracy: 0.8722 - val_loss: 0.5334 - val_accuracy: 0.7760
# Epoch 82/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2847 - accuracy: 0.8833 - val_loss: 0.4250 - val_accuracy: 0.8203
# Epoch 83/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2670 - accuracy: 0.8863 - val_loss: 0.5024 - val_accuracy: 0.7708
# Epoch 84/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3032 - accuracy: 0.8716 - val_loss: 0.5926 - val_accuracy: 0.7708
# Epoch 85/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2875 - accuracy: 0.8814 - val_loss: 1.4795 - val_accuracy: 0.5938
# Epoch 86/200
# 205/205 [==============================] - 8s 41ms/step - loss: 0.2995 - accuracy: 0.8680 - val_loss: 0.5829 - val_accuracy: 0.7604
# Epoch 87/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3127 - accuracy: 0.8716 - val_loss: 1.2945 - val_accuracy: 0.5339
# Epoch 88/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2681 - accuracy: 0.8924 - val_loss: 0.4987 - val_accuracy: 0.8047
# Epoch 89/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2911 - accuracy: 0.8808 - val_loss: 0.5522 - val_accuracy: 0.7682
# Epoch 90/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2762 - accuracy: 0.8771 - val_loss: 0.6514 - val_accuracy: 0.7630
# Epoch 91/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2559 - accuracy: 0.8888 - val_loss: 0.6002 - val_accuracy: 0.7604
# Epoch 92/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2486 - accuracy: 0.8998 - val_loss: 0.9669 - val_accuracy: 0.6797
# Epoch 93/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2726 - accuracy: 0.8851 - val_loss: 1.1433 - val_accuracy: 0.6328
# Epoch 94/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2485 - accuracy: 0.8906 - val_loss: 0.4424 - val_accuracy: 0.8125
# Epoch 95/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2923 - accuracy: 0.8753 - val_loss: 0.5491 - val_accuracy: 0.7604
# Epoch 96/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.3061 - accuracy: 0.8735 - val_loss: 2.3830 - val_accuracy: 0.4766
# Epoch 97/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2525 - accuracy: 0.8900 - val_loss: 0.5480 - val_accuracy: 0.7682
# Epoch 98/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2711 - accuracy: 0.8826 - val_loss: 0.7166 - val_accuracy: 0.7240
# Epoch 99/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2558 - accuracy: 0.8973 - val_loss: 1.5659 - val_accuracy: 0.6094
# Epoch 100/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2644 - accuracy: 0.8949 - val_loss: 0.8900 - val_accuracy: 0.6641
# Epoch 101/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2539 - accuracy: 0.8918 - val_loss: 0.6395 - val_accuracy: 0.7630
# Epoch 102/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2511 - accuracy: 0.8930 - val_loss: 0.7051 - val_accuracy: 0.7448
# Epoch 103/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2600 - accuracy: 0.8875 - val_loss: 1.2881 - val_accuracy: 0.6719
# Epoch 104/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2477 - accuracy: 0.8936 - val_loss: 2.4848 - val_accuracy: 0.4531
# Epoch 105/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2455 - accuracy: 0.9059 - val_loss: 0.5417 - val_accuracy: 0.7917
# Epoch 106/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2490 - accuracy: 0.8961 - val_loss: 0.6240 - val_accuracy: 0.7734
# Epoch 107/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2659 - accuracy: 0.8839 - val_loss: 0.9738 - val_accuracy: 0.6719
# Epoch 108/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2694 - accuracy: 0.8833 - val_loss: 0.5187 - val_accuracy: 0.8021
# Epoch 109/200
# 205/205 [==============================] - 8s 41ms/step - loss: 0.2558 - accuracy: 0.8875 - val_loss: 1.6722 - val_accuracy: 0.5052
# Epoch 110/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2358 - accuracy: 0.9053 - val_loss: 1.2219 - val_accuracy: 0.6432
# Epoch 111/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2542 - accuracy: 0.8973 - val_loss: 0.8940 - val_accuracy: 0.7214
# Epoch 112/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2546 - accuracy: 0.8973 - val_loss: 2.1426 - val_accuracy: 0.4661
# Epoch 113/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2366 - accuracy: 0.9046 - val_loss: 1.1105 - val_accuracy: 0.6589
# Epoch 114/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2546 - accuracy: 0.8961 - val_loss: 1.9642 - val_accuracy: 0.5000
# Epoch 115/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2525 - accuracy: 0.8936 - val_loss: 0.6390 - val_accuracy: 0.7422
# Epoch 116/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2226 - accuracy: 0.9022 - val_loss: 1.1553 - val_accuracy: 0.6302
# Epoch 117/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2477 - accuracy: 0.8967 - val_loss: 1.7061 - val_accuracy: 0.5495
# Epoch 118/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2831 - accuracy: 0.8808 - val_loss: 0.8081 - val_accuracy: 0.7188
# Epoch 119/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2529 - accuracy: 0.8991 - val_loss: 0.7278 - val_accuracy: 0.7500
# Epoch 120/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2307 - accuracy: 0.9053 - val_loss: 0.6436 - val_accuracy: 0.7604
# Epoch 121/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2417 - accuracy: 0.9016 - val_loss: 1.0309 - val_accuracy: 0.6771
# Epoch 122/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2917 - accuracy: 0.8735 - val_loss: 0.6407 - val_accuracy: 0.7526
# Epoch 123/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2324 - accuracy: 0.9126 - val_loss: 0.9402 - val_accuracy: 0.6719
# Epoch 124/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2013 - accuracy: 0.9181 - val_loss: 0.7444 - val_accuracy: 0.7396
# Epoch 125/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2307 - accuracy: 0.8998 - val_loss: 0.6726 - val_accuracy: 0.7370
# Epoch 126/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2230 - accuracy: 0.9083 - val_loss: 3.0346 - val_accuracy: 0.5703
# Epoch 127/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2411 - accuracy: 0.9004 - val_loss: 1.4533 - val_accuracy: 0.6016
# Epoch 128/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2226 - accuracy: 0.9059 - val_loss: 0.5231 - val_accuracy: 0.7865
# Epoch 129/200
# 205/205 [==============================] - 8s 41ms/step - loss: 0.2340 - accuracy: 0.9040 - val_loss: 0.4724 - val_accuracy: 0.8281
# Epoch 130/200
# 205/205 [==============================] - 8s 41ms/step - loss: 0.2412 - accuracy: 0.8894 - val_loss: 0.5113 - val_accuracy: 0.8047
# Epoch 131/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2133 - accuracy: 0.9132 - val_loss: 0.6195 - val_accuracy: 0.7917
# Epoch 132/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2413 - accuracy: 0.9022 - val_loss: 0.4813 - val_accuracy: 0.8125
# Epoch 133/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2145 - accuracy: 0.9053 - val_loss: 0.7568 - val_accuracy: 0.7318
# Epoch 134/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2308 - accuracy: 0.8961 - val_loss: 1.1315 - val_accuracy: 0.6615
# Epoch 135/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2280 - accuracy: 0.9028 - val_loss: 0.7675 - val_accuracy: 0.7370
# Epoch 136/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2342 - accuracy: 0.9040 - val_loss: 0.8182 - val_accuracy: 0.7422
# Epoch 137/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2236 - accuracy: 0.9034 - val_loss: 3.4091 - val_accuracy: 0.5703
# Epoch 138/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2452 - accuracy: 0.8930 - val_loss: 1.5761 - val_accuracy: 0.6016
# Epoch 139/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2332 - accuracy: 0.8991 - val_loss: 1.0430 - val_accuracy: 0.6432
# Epoch 140/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2086 - accuracy: 0.9144 - val_loss: 0.7099 - val_accuracy: 0.7552
# Epoch 141/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2169 - accuracy: 0.9156 - val_loss: 0.6442 - val_accuracy: 0.7396
# Epoch 142/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2284 - accuracy: 0.9059 - val_loss: 1.3593 - val_accuracy: 0.6484
# Epoch 143/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2233 - accuracy: 0.9101 - val_loss: 0.7325 - val_accuracy: 0.7578
# Epoch 144/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2263 - accuracy: 0.9046 - val_loss: 1.9573 - val_accuracy: 0.5651
# Epoch 145/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2280 - accuracy: 0.9077 - val_loss: 0.7579 - val_accuracy: 0.7109
# Epoch 146/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.1893 - accuracy: 0.9254 - val_loss: 1.1562 - val_accuracy: 0.6901
# Epoch 147/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2124 - accuracy: 0.9181 - val_loss: 0.8952 - val_accuracy: 0.6771
# Epoch 148/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2286 - accuracy: 0.9016 - val_loss: 1.4510 - val_accuracy: 0.6146
# Epoch 149/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2135 - accuracy: 0.9260 - val_loss: 1.1782 - val_accuracy: 0.6901
# Epoch 150/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2158 - accuracy: 0.9150 - val_loss: 1.6509 - val_accuracy: 0.5703
# Epoch 151/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2463 - accuracy: 0.8949 - val_loss: 0.5366 - val_accuracy: 0.7474
# Epoch 152/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.1994 - accuracy: 0.9199 - val_loss: 1.4720 - val_accuracy: 0.6380
# Epoch 153/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2095 - accuracy: 0.9114 - val_loss: 0.7082 - val_accuracy: 0.7656
# Epoch 154/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2094 - accuracy: 0.9120 - val_loss: 0.7077 - val_accuracy: 0.7604
# Epoch 155/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.1859 - accuracy: 0.9224 - val_loss: 0.5056 - val_accuracy: 0.7812
# Epoch 156/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2171 - accuracy: 0.9059 - val_loss: 0.8703 - val_accuracy: 0.6927
# Epoch 157/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2394 - accuracy: 0.9046 - val_loss: 0.6429 - val_accuracy: 0.7474
# Epoch 158/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.1967 - accuracy: 0.9260 - val_loss: 0.7125 - val_accuracy: 0.7578
# Epoch 159/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2321 - accuracy: 0.9022 - val_loss: 0.5106 - val_accuracy: 0.7943
# Epoch 160/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2144 - accuracy: 0.9089 - val_loss: 0.8606 - val_accuracy: 0.7214
# Epoch 161/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2050 - accuracy: 0.9211 - val_loss: 0.6454 - val_accuracy: 0.7630
# Epoch 162/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.1882 - accuracy: 0.9254 - val_loss: 0.6076 - val_accuracy: 0.7630
# Epoch 163/200
# 205/205 [==============================] - 8s 41ms/step - loss: 0.2048 - accuracy: 0.9175 - val_loss: 0.8694 - val_accuracy: 0.7370
# Epoch 164/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2344 - accuracy: 0.8979 - val_loss: 0.6050 - val_accuracy: 0.7656
# Epoch 165/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2021 - accuracy: 0.9187 - val_loss: 0.6765 - val_accuracy: 0.7604
# Epoch 166/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2147 - accuracy: 0.9181 - val_loss: 0.6377 - val_accuracy: 0.7604
# Epoch 167/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.1944 - accuracy: 0.9267 - val_loss: 1.0614 - val_accuracy: 0.6901
# Epoch 168/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2013 - accuracy: 0.9187 - val_loss: 0.5409 - val_accuracy: 0.7917
# Epoch 169/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.1820 - accuracy: 0.9322 - val_loss: 1.1925 - val_accuracy: 0.6146
# Epoch 170/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.1869 - accuracy: 0.9199 - val_loss: 0.7383 - val_accuracy: 0.7500
# Epoch 171/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.1852 - accuracy: 0.9267 - val_loss: 1.1495 - val_accuracy: 0.6432
# Epoch 172/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.1965 - accuracy: 0.9181 - val_loss: 1.1431 - val_accuracy: 0.6927
# Epoch 173/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.1890 - accuracy: 0.9199 - val_loss: 1.7297 - val_accuracy: 0.6198
# Epoch 174/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.1996 - accuracy: 0.9199 - val_loss: 0.6665 - val_accuracy: 0.7682
# Epoch 175/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.1916 - accuracy: 0.9211 - val_loss: 0.8341 - val_accuracy: 0.7500
# Epoch 176/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2044 - accuracy: 0.9156 - val_loss: 0.5112 - val_accuracy: 0.7865
# Epoch 177/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2050 - accuracy: 0.9114 - val_loss: 0.5606 - val_accuracy: 0.8099
# Epoch 178/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.1873 - accuracy: 0.9248 - val_loss: 1.4294 - val_accuracy: 0.6328
# Epoch 179/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.1635 - accuracy: 0.9322 - val_loss: 0.9852 - val_accuracy: 0.7292
# Epoch 180/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.1634 - accuracy: 0.9370 - val_loss: 0.6139 - val_accuracy: 0.8047
# Epoch 181/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.1944 - accuracy: 0.9236 - val_loss: 0.5792 - val_accuracy: 0.7995
# Epoch 182/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.1799 - accuracy: 0.9291 - val_loss: 4.0895 - val_accuracy: 0.4349
# Epoch 183/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.1837 - accuracy: 0.9273 - val_loss: 0.4867 - val_accuracy: 0.8229
# Epoch 184/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2027 - accuracy: 0.9205 - val_loss: 0.8687 - val_accuracy: 0.7526
# Epoch 185/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.1830 - accuracy: 0.9309 - val_loss: 0.6192 - val_accuracy: 0.7995
# Epoch 186/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.1728 - accuracy: 0.9340 - val_loss: 1.3381 - val_accuracy: 0.6094
# Epoch 187/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.2043 - accuracy: 0.9138 - val_loss: 0.9736 - val_accuracy: 0.7161
# Epoch 188/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.1959 - accuracy: 0.9193 - val_loss: 2.4831 - val_accuracy: 0.5703
# Epoch 189/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.1677 - accuracy: 0.9419 - val_loss: 3.5315 - val_accuracy: 0.4401
# Epoch 190/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.1657 - accuracy: 0.9346 - val_loss: 0.7118 - val_accuracy: 0.7682
# Epoch 191/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.1867 - accuracy: 0.9181 - val_loss: 0.7072 - val_accuracy: 0.7682
# Epoch 192/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.1917 - accuracy: 0.9236 - val_loss: 0.6837 - val_accuracy: 0.7734
# Epoch 193/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.1746 - accuracy: 0.9358 - val_loss: 0.6358 - val_accuracy: 0.7786
# Epoch 194/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.1884 - accuracy: 0.9224 - val_loss: 1.1386 - val_accuracy: 0.6328
# Epoch 195/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.1714 - accuracy: 0.9346 - val_loss: 0.6215 - val_accuracy: 0.7969
# Epoch 196/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.1696 - accuracy: 0.9407 - val_loss: 0.5946 - val_accuracy: 0.7995
# Epoch 197/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.1654 - accuracy: 0.9383 - val_loss: 0.7450 - val_accuracy: 0.7760
# Epoch 198/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.1650 - accuracy: 0.9383 - val_loss: 0.6470 - val_accuracy: 0.7812
# Epoch 199/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.1788 - accuracy: 0.9267 - val_loss: 0.6632 - val_accuracy: 0.7812
# Epoch 200/200
# 205/205 [==============================] - 8s 40ms/step - loss: 0.1947 - accuracy: 0.9236 - val_loss: 3.1119 - val_accuracy: 0.4792

# %%
plot_graphs(history2, "accuracy")
plot_graphs(history2, "loss")

# %%
# delete the data

shutil.rmtree('/tmp/Liver_'+equipment)

# %%
import os, signal
train_generator, test_generator
os.kill(os.getpid(),signal.SIGKILL)
